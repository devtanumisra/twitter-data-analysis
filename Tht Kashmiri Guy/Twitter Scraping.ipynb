# %%
import requests
import wget

# %%
import tweepy

# %%
# Your app's bearer token can be found under the Authentication Tokens section
# of the Keys and Tokens tab of your app, under the
# Twitter Developer Portal Projects & Apps page at
# https://developer.twitter.com/en/portal/projects-and-apps
bearer_token = "AAAAAAAAAAAAAAAAAAAAABvFhgEAAAAAWxWdLEnp6pZJsYMUYAi%2BvFrM5oY%3DrtKXQDsTRS4fXYn44RofMurkHUiMeKlBNVaoAHgJAkVg8DD0GS"

# Your app's API/consumer key and secret can be found under the Consumer Keys
# section of the Keys and Tokens tab of your app, under the
# Twitter Developer Portal Projects & Apps page at
# https://developer.twitter.com/en/portal/projects-and-apps
consumer_key = "r5DowaN8eoM9r1PgQ2ezR6UoN"
consumer_secret = "Z29vyH4fDqlYIRhFyKBgpGvcdTOCdpAhqvau53qsP9KVAlFlbS"

# Your account's (the app owner's account's) access token and secret for your
# app can be found under the Authentication Tokens section of the
# Keys and Tokens tab of your app, under the
# Twitter Developer Portal Projects & Apps page at
# https://developer.twitter.com/en/portal/projects-and-apps
access_token = "1576162990247682049-EsSWVFhd5Z3DrXFZiDkHpN57eRTGXu"
access_token_secret = "qAExjQzAHHkf4FN1LAfZHGocw2E98djMZvmNvEskJQRyr"

# %%
# You can authenticate as your app with just your bearer token
client = tweepy.Client(bearer_token=bearer_token)

# %%
# If the authentication was successful, this should print the
# screen name / username of the account
print(client)
# Out:
# <tweepy.client.Client object at 0x000001E3A6E14400>

# %% [markdown]
# ## OPEN A CSV FILE AND WRITE THE RESPONSE TO IT

# %%
import csv

# %%
def getComments(id):
    api="https://api.twitter.com/2/tweets/search/recent?query=conversation_id:" + str(id) + "&tweet.fields=in_reply_to_user_id,author_id,created_at,conversation_id"
    response = requests.get(api,headers={"Authorization":"Bearer AAAAAAAAAAAAAAAAAAAAAEnThwEAAAAAO1yTEzATZBIFaa6R7lw8TH7bK3U%3DXswu28WNIUXOUnucNkz7AA0y4U9qxyzBHxsPEs3eDrC3WLmm9o"})
    #print(response.json())
    return response

# %%
def getImageURL(id):
    api="https://api.twitter.com/2/tweets?ids="+ str(id) +"&expansions=attachments.media_keys&media.fields=duration_ms,height,media_key,preview_image_url,public_metrics,type,url,width,alt_text"
    response = requests.get(api,headers={"Authorization":"Bearer AAAAAAAAAAAAAAAAAAAAAEnThwEAAAAAO1yTEzATZBIFaa6R7lw8TH7bK3U%3DXswu28WNIUXOUnucNkz7AA0y4U9qxyzBHxsPEs3eDrC3WLmm9o"})
    str1 = None
    if 'includes'in response.json():
        if 'url'in response.json()['includes']['media'][0]:
            str1 = str(response.json()['includes']['media'][0]['url'])
        elif 'preview_image_url'in response.json()['includes']['media'][0]:
            str1 = str(response.json()['includes']['media'][0]['preview_image_url'])
    return str1

# %%
def downloadImage(url):
    file_name = wget.download(url)
    return file_name

# %%
def getPosts(response,writer):
    data = response.data
    t=0
    for trump in data:
        t+=1
        print()
        print("Data",t)
        print(trump.id)
        print(trump.text)
        st = trump.text
        index = st.rfind("https")
        
        print('\n')
    
        #api ="https://api.twitter.com/2/tweets/search/recent?query=conversation_id:" + str(trump.id) + "&tweet.fields=in_reply_to_user_id,author_id,created_at,conversation_id"
        res = getConversationId(trump.id)
        #print("Comments!!",t)
        conversation_id = res.json()['data'][0]['conversation_id']
        
        print('Comments:\n')
        res = getComments(conversation_id)
        
        imageURL = getImageURL(trump.id)
        file = ''
        
        if imageURL:
            imageFile = downloadImage(imageURL)
            file = imageFile
            
        
        post_row = ["P:"+str(trump.id), '', file, trump.text, 'Caption', "NA" if (index == -1) else st[index:], '', '', '', '', '', '']
        writer.writerow(post_row)
                 
        
        if 'data' not in res.json():
            print("No Comments")
        else:
            #print(res.json())
            for data in res.json()['data']:
                #print(data['text'])
                cmnt_row = ["P:"+str(trump.id), '', '', data['text'], 'Additional Comment','NA', '', '', '', '', '', '']
                writer.writerow(cmnt_row)

# %%
def getConversationId(id):
    api = "https://api.twitter.com/2/tweets?ids=" + str(id) + "&tweet.fields=author_id,conversation_id,created_at,in_reply_to_user_id,referenced_tweets&expansions=author_id,in_reply_to_user_id,referenced_tweets.id&user.fields=name,username"
    response = requests.get(api,headers={"Authorization":"Bearer AAAAAAAAAAAAAAAAAAAAAEnThwEAAAAAO1yTEzATZBIFaa6R7lw8TH7bK3U%3DXswu28WNIUXOUnucNkz7AA0y4U9qxyzBHxsPEs3eDrC3WLmm9o"})
    #print(response.json())
    return response

# %%
f = open('thtKashmiriGuy.csv', 'w', encoding='UTF8',newline='')
writer = csv.writer(f)

#Insert header into csv file
header = ['POST_ID','POST_LINK','IMAGES_ID','Text','Text Type', 'MEDIA_URL', 'Text OCR', 'Language of Text','Hate Speech','Profane','Sentiment','Targeted Insult']
writer.writerow(header)

response = client.search_recent_tweets("ThtKashmiriGuy", max_results=100)
getPosts(response,writer)
#print(response)
f.close()
# Out:
# Data 1
# 1583978081500286976
# @ThtKashmiriGuy @prafullaketkar @amritabhinder @KapilMishra_IND @smritiirani Well done 👍
#
#
# Comments:
#
#
# Data 2
# 1583978051657904128
# RT @ThtKashmiriGuy: Indian Army launched a Swift rescue operation in Gurez sector of Kashmir 🍁 to save a precious Life
#
# Operation lasted fo…
#
#
# Comments:
#
# No Comments
#
# Data 3
# 1583873315503906817
# Hey @KhaledBeydoun look what your uncle is doing...!!!!
# @Reuters @nypost @FoxNews @RNCResearch @washingtonpost @smh @TarekFatah @ThtKashmiriGuy @TheDeepak2022  @TajinderBagga https://t.co/9xkY8kia5A
#
#
# Comments:
#
# No Comments
#
# Data 4
# 1583777731820412928
# RT @ThtKashmiriGuy: Another Kashmiri Hindu Poran Krishen Bhat shot dead in Kashmir.
#
# Day is not far when you will hear about Kashmiri Pandi…
#
#
# Comments:
#
# No Comments
#
# Data 5
# 1583777682080219136
# RT @ThtKashmiriGuy: Being hindu, has become our crime!! https://t.co/zQrt54io8C
#
#
# Comments:
#
# 100% [............................................................................] 101217 / 101217No Comments
#
# Data 6
# 1583777544331223040
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 7
# 1583741056428158978
# Save us 🙏❣️
# #BJP jago
# #KashmiriPandits
# @Kporgall
# @jammukasmirhc
# @pandits_kashmir
# @BattaKashmiri
# @ThtKashmiriGuy
# @spvaid
# @jammu_tweeter
# @official_Arnab_
# @sudhirchaudhary
# @PTI_News
# @ANI
# @CNNnews18
# @BBCHindi
# @UN
# @UNICEF
# @TOIIndiaNews
# @GeneralBakshi
# @Tiny_Dhillon https://t.co/gYfiQNFAjx
#
#
# Comments:
#
# No Comments
#
# Data 8
# 1583722843899994112
# RT @sawarathiajss: @ThtKashmiriGuy All these wallah allah songs shud be banned frm hindu functions
#
#
# Comments:
#
# No Comments
#
# Data 9
# 1583696220350205952
# RT @hariom5sharma: @ThtKashmiriGuy @himantabiswa 😂😂😂
#
#
# Comments:
#
# No Comments
#
# Data 10
# 1583491980662669312
# @BefittingFacts @ThePollLady @JaipurDialogues @ThtKashmiriGuy @theskindoctor13 @thehawkeyex @iamkamyabuch https://t.co/Snh5ZvAEmv
#
#
# Comments:
#
# No Comments
#
# Data 11
# 1583481497356754945
# @ThtKashmiriGuy Very very painful to even see this, imagine what happens to those who have actually lost there loved one. Om Shanti.
#
#
# Comments:
#
#
# Data 12
# 1583460956213940224
# @mowgli233 @AkashMi43542498 @realmeIndia Oh, thats oxymoron combo I felt. LOL
# Most ppl who showcase progressive in all pride, often turns out to be cowards who spend their little courage in preaching Hndus what to do what not to do, but shiver if the matter ever is about the bl00dthirsty. so..
# https://t.co/sESSuY2Jix
#
#
# Comments:
#
#
# Data 13
# 1583346115885223937
# RT @ThtKashmiriGuy: Another Kashmiri Hindu Poran Krishen Bhat shot dead in Kashmir.
#
# Day is not far when you will hear about Kashmiri Pandi…
#
#
# Comments:
#
# No Comments
#
# Data 14
# 1583324607268159490
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 15
# 1583221238121791489
# @Varun_G_5 @ThtKashmiriGuy https://t.co/A3v08gco8U
#
#
# Comments:
#
# 100% [..............................................................................] 15652 / 15652
# Data 16
# 1583210428460462081
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 17
# 1583133323588952065
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 18
# 1583047790703546368
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 19
# 1583042317300428801
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 20
# 1583041401868398592
# RT @shah_0601: @ThtKashmiriGuy Cricketers and bollywoodians are somewhat similar.
#
#
# Comments:
#
# No Comments
#
# Data 21
# 1583041168329543682
# RT @BHARATIYASEEKER: @ThtKashmiriGuy @VlKASPR0NAM0 https://t.co/HVLGDRrHml
#
#
# Comments:
#
# 100% [..............................................................................] 57790 / 57790No Comments
#
# Data 22
# 1583041123391803393
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 23
# 1583030572435525633
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 24
# 1583011352913670144
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 25
# 1583009412813578241
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 26
# 1582990651498844160
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 27
# 1582984685789261824
# RT @follow2deep2: So basically, Parashuaram is what the current day human would be who could also use tools, in other words Homo Sapien.
# @T…
#
#
# Comments:
#
# No Comments
#
# Data 28
# 1582981021695627265
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 29
# 1582978806935334912
# Brilliant Tweet @ThtKashmiriGuy https://t.co/Rcp037tpQ4
#
#
# Comments:
#
# 100% [..............................................................................] 58139 / 58139No Comments
#
# Data 30
# 1582975912324124672
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 31
# 1582964733518393345
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 32
# 1582963667686998016
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 33
# 1582958033541660672
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 34
# 1582957690976112643
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 35
# 1582955794177265664
# RT @extremerage2: @ThtKashmiriGuy What else can be expected from them? They are just a bunch of rich chappris playing cricket. What they kn…
#
#
# Comments:
#
# No Comments
#
# Data 36
# 1582955737797402624
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 37
# 1582954262354857985
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 38
# 1582945203618390016
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 39
# 1582943307151265793
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 40
# 1582938892155891712
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 41
# 1582936386000551936
# RT @ThtKashmiriGuy: Being hindu, has become our crime!! https://t.co/zQrt54io8C
#
#
# Comments:
#
# 100% [............................................................................] 101217 / 101217No Comments
#
# Data 42
# 1582929981025701888
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 43
# 1582924211118837760
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 44
# 1582912771356000256
# @Sassy_Hindu @ThtKashmiriGuy Those things we can't ask 🤣🤣🤣
#
#
# Comments:
#
#
# Data 45
# 1582895755928670208
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 46
# 1582890882508148739
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 47
# 1582887094095347712
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 48
# 1582886015622320128
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 49
# 1582872743204114432
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 50
# 1582872173324009472
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 51
# 1582825090378448898
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 52
# 1582810545161670657
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 53
# 1582804643570413568
# @ThtKashmiriGuy I could look at Sachin, Ganguly and Dravid and VVS and know they repped India. Not sure about all this daari wale players.
#
#
# Comments:
#
#
# Data 54
# 1582798965472649217
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 55
# 1582798040943185920
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 56
# 1582797985855180801
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 57
# 1582797352061894656
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 58
# 1582796790109470721
# @bcci @ImRo45 @imVkohli ye sb log mumbai uri pulwama sare attack bhul gye hai..
# Aggression ke sath khelo unke sath dar ke nahi..they can't  afford you unko khelna hi padega tumhare sath..bhaichara mat bnawo zyada. https://t.co/8Vi82h5sdk
#
#
# Comments:
#
# No Comments
#
# Data 59
# 1582795390319222784
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 60
# 1582793379175600128
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 61
# 1582784885424476160
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 62
# 1582784449401745408
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 63
# 1582784233713856513
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 64
# 1582780415664074752
# RT @ThtKashmiriGuy: Imagine her pain hindus🙏 https://t.co/g0snWbf50s
#
#
# Comments:
#
# 100% [............................................................................] 126066 / 126066No Comments
#
# Data 65
# 1582778692161658882
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 66
# 1582776099938787332
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 67
# 1582774177898979329
# @ThtKashmiriGuy @Sassy_Hindu #BoycottKOTAKMahindraBank @nsitharamanoffc @PMOIndia Through ds message I would like २ bring ur at10tion towards d deficiency in bank srvc in withdrawing cash from KOTAK MAHINDRA BANK ATM on Raksha Bandhan, being unresolved till date Complaint No. DEABD/E/2022/59860 @udaykotak
#
#
# Comments:
#
#
# Data 68
# 1582774067391651851
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 69
# 1582773171274809345
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 70
# 1582772522042667008
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 71
# 1582771476318801920
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 72
# 1582770548517371908
# @ThtKashmiriGuy @Sassy_Hindu Can we ask justice for Pandits &amp; our soldiers from Abdullah &amp; sons ??
#
#
# Comments:
#
#
# Data 73
# 1582770340064657410
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 74
# 1582770102788714496
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 75
# 1582769131434446850
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 76
# 1582768883802738688
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 77
# 1582768618567512064
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 78
# 1582768586157719553
# @ThtKashmiriGuy @Sassy_Hindu Justice means rule of muslims . Kafirs should stay as second class citizens .
#
#
# Comments:
#
#
# Data 79
# 1582768506927710209
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 80
# 1582768126738907136
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 81
# 1582766466633723904
# @mini_razdan10 @Imamofpeace @ThtKashmiriGuy @jihadwatchRS @Voice_For_India @RadharamnDas @ExmuslimSahil @TarekFatah @JitendraNTyagi @KapilMishra_IND @SanjeevSanskrit @OpIndia_com @SudarshanNewsTV @Shehzad_Ind @barbarindian @republic @GemsOfBollywood @geertwilderspvv @arifaajakia
#
#
# Comments:
#
#
# Data 82
# 1582762875093155840
# @ThtKashmiriGuy 🤔
#
#
# Comments:
#
#
# Data 83
# 1582762837273120769
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 84
# 1582757434330075136
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 85
# 1582757125310545922
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 86
# 1582756966107336707
# @ThtKashmiriGuy What else can be expected from them? They are just a bunch of rich chappris playing cricket. What they know about sacrifices made by real men? Even today's feminist girls will have more masculinity than these weak soft sensitive childrens.
#
#
# Comments:
#
#
# Data 87
# 1582755042100404224
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 88
# 1582753878986358784
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 89
# 1582752694602960898
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 90
# 1582744930522255361
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 91
# 1582738638617874432
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 92
# 1582738535643172865
# @RudraVS @jytkoul @manojsinha_ @AdityaRajKaul @Sushilpandit_34 @LalitAmbardar Musical chairs have never solved any problem leave alone vexed Kashmir problem. You have to strike at the root that's a madrasa which creates frankenstein monsters. @narendramodi @majorgauravarya @ARanganathan72 @ThtKashmiriGuy
#
#
# Comments:
#
#
# Data 93
# 1582738421717487616
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 94
# 1582727395844689921
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 95
# 1582727226562605056
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 96
# 1582724723410362370
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 97
# 1582721678756704256
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 98
# 1582713814520573952
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 99
# 1582712318919524352
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
#
# Data 100
# 1582708629782040576
# RT @ThtKashmiriGuy: Offering without any Caption https://t.co/b2XNhDTgrN
#
#
# Comments:
#
# 100% [............................................................................] 215947 / 215947No Comments
