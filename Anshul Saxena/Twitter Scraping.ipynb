# %%
import requests
import wget

# %%
import tweepy

# %%
# Your app's bearer token can be found under the Authentication Tokens section
# of the Keys and Tokens tab of your app, under the
# Twitter Developer Portal Projects & Apps page at
# https://developer.twitter.com/en/portal/projects-and-apps
bearer_token = "AAAAAAAAAAAAAAAAAAAAABvFhgEAAAAAWxWdLEnp6pZJsYMUYAi%2BvFrM5oY%3DrtKXQDsTRS4fXYn44RofMurkHUiMeKlBNVaoAHgJAkVg8DD0GS"

# Your app's API/consumer key and secret can be found under the Consumer Keys
# section of the Keys and Tokens tab of your app, under the
# Twitter Developer Portal Projects & Apps page at
# https://developer.twitter.com/en/portal/projects-and-apps
consumer_key = "r5DowaN8eoM9r1PgQ2ezR6UoN"
consumer_secret = "Z29vyH4fDqlYIRhFyKBgpGvcdTOCdpAhqvau53qsP9KVAlFlbS"

# Your account's (the app owner's account's) access token and secret for your
# app can be found under the Authentication Tokens section of the
# Keys and Tokens tab of your app, under the
# Twitter Developer Portal Projects & Apps page at
# https://developer.twitter.com/en/portal/projects-and-apps
access_token = "1576162990247682049-EsSWVFhd5Z3DrXFZiDkHpN57eRTGXu"
access_token_secret = "qAExjQzAHHkf4FN1LAfZHGocw2E98djMZvmNvEskJQRyr"

# %%
# You can authenticate as your app with just your bearer token
client = tweepy.Client(bearer_token=bearer_token)

# %%
# If the authentication was successful, this should print the
# screen name / username of the account
print(client)
# Out:
# <tweepy.client.Client object at 0x000001CD43A758B0>

# %% [markdown]
# ## OPEN A CSV FILE AND WRITE THE RESPONSE TO IT

# %%
import csv

# %%
def getComments(id):
    api="https://api.twitter.com/2/tweets/search/recent?query=conversation_id:" + str(id) + "&tweet.fields=in_reply_to_user_id,author_id,created_at,conversation_id"
    response = requests.get(api,headers={"Authorization":"Bearer AAAAAAAAAAAAAAAAAAAAAEnThwEAAAAAO1yTEzATZBIFaa6R7lw8TH7bK3U%3DXswu28WNIUXOUnucNkz7AA0y4U9qxyzBHxsPEs3eDrC3WLmm9o"})
    #print(response.json())
    return response

# %%
def getImageURL(id):
    api="https://api.twitter.com/2/tweets?ids="+ str(id) +"&expansions=attachments.media_keys&media.fields=duration_ms,height,media_key,preview_image_url,public_metrics,type,url,width,alt_text"
    response = requests.get(api,headers={"Authorization":"Bearer AAAAAAAAAAAAAAAAAAAAAEnThwEAAAAAO1yTEzATZBIFaa6R7lw8TH7bK3U%3DXswu28WNIUXOUnucNkz7AA0y4U9qxyzBHxsPEs3eDrC3WLmm9o"})
    str1 = None
    if 'includes'in response.json():
        if 'url'in response.json()['includes']['media'][0]:
            str1 = str(response.json()['includes']['media'][0]['url'])
        elif 'preview_image_url'in response.json()['includes']['media'][0]:
            str1 = str(response.json()['includes']['media'][0]['preview_image_url'])
    return str1

# %%
def downloadImage(url):
    file_name = wget.download(url)
    return file_name

# %%
def getPosts(response,writer):
    data = response.data
    t=0
    for trump in data:
        t+=1
        print()
        print("Data",t)
        print(trump.id)
        print(trump.text)
        st = trump.text
        index = st.rfind("https")
        
        print('\n')
    
        #api ="https://api.twitter.com/2/tweets/search/recent?query=conversation_id:" + str(trump.id) + "&tweet.fields=in_reply_to_user_id,author_id,created_at,conversation_id"
        res = getConversationId(trump.id)
        #print("Comments!!",t)
        conversation_id = res.json()['data'][0]['conversation_id']
        
        print('Comments:\n')
        res = getComments(conversation_id)
        
        imageURL = getImageURL(trump.id)
        file = ''
        
        if imageURL:
            imageFile = downloadImage(imageURL)
            file = imageFile
            
        
        post_row = ["P:"+str(trump.id), '', file, trump.text, 'Caption', imageURL, '', '', '', '', '', '']
        writer.writerow(post_row)
                 
        
        if 'data' not in res.json():
            print("No Comments")
        else:
            #print(res.json())
            for data in res.json()['data']:
                #print(data['text'])
                cmnt_row = ["P:"+str(trump.id), '', '', data['text'], 'Additional Comment','', '', '', '', '', '', '']
                writer.writerow(cmnt_row)

# %%
def getConversationId(id):
    api = "https://api.twitter.com/2/tweets?ids=" + str(id) + "&tweet.fields=author_id,conversation_id,created_at,in_reply_to_user_id,referenced_tweets&expansions=author_id,in_reply_to_user_id,referenced_tweets.id&user.fields=name,username"
    response = requests.get(api,headers={"Authorization":"Bearer AAAAAAAAAAAAAAAAAAAAAEnThwEAAAAAO1yTEzATZBIFaa6R7lw8TH7bK3U%3DXswu28WNIUXOUnucNkz7AA0y4U9qxyzBHxsPEs3eDrC3WLmm9o"})
    #print(response.json())
    return response

# %%
f = open('ask_anshul.csv', 'w', encoding='UTF8',newline='')
writer = csv.writer(f)

#Insert header into csv file
header = ['POST_ID','POST_LINK','IMAGES_ID','Text','Text Type', 'MEDIA_URL', 'Text OCR', 'Language of Text','Hate Speech','Profane','Sentiment','Targeted Insult']
writer.writerow(header)

response = client.search_recent_tweets("AskAnshul", max_results=100)
getPosts(response,writer)
#print(response)
f.close()
# Out:
# Data 1
# 1584069089076871168
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 2
# 1584069025570529280
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 3
# 1584069025042419712
# @AskAnshul My god West Bengal is heading towards a very wrong direction
#
#
# Comments:
#
#
# Data 4
# 1584068869429530624
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 5
# 1584068814375129088
# RT @AskAnshul: Now, The Bell House deleted tweet
#
# Diwali party organised to raise funds for Pakistan, proceeds go to Alkhidmat Foundation…
#
#
# Comments:
#
# No Comments
#
# Data 6
# 1584068691775262720
# RT @AskAnshul: Now, The Bell House deleted tweet
#
# Diwali party organised to raise funds for Pakistan, proceeds go to Alkhidmat Foundation…
#
#
# Comments:
#
# No Comments
#
# Data 7
# 1584068691771392002
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 8
# 1584068636813033472
# RT @AskAnshul: Now, The Bell House deleted tweet
#
# Diwali party organised to raise funds for Pakistan, proceeds go to Alkhidmat Foundation…
#
#
# Comments:
#
# No Comments
#
# Data 9
# 1584068633914843136
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 10
# 1584068623328768000
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 11
# 1584068612276768769
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 12
# 1584068587802984448
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 13
# 1584068545088221186
# RT @MinorityMjs: అమ్మ @padma_vasireddy గారు మికు ఏ మాత్రం కుల గజ్జి లేకపోతే ఈ బొరుగడ్డ అనే లుచ్చా గాడు పవన్ కళ్యాణ్ గారి ఫ్యామిలీ మీద ఇంతా…
#
#
# Comments:
#
# No Comments
#
# Data 14
# 1584068480017793026
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 15
# 1584068466868617216
# @SureshS21753809 @AskAnshul Praise the scientists and people working at ISRO who have done a remarkable job inspite of budget cuts by your masters
#
#
# Comments:
#
#
# Data 16
# 1584068455300362246
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 17
# 1584068373301710848
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 18
# 1584068371603394560
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 19
# 1584068365311651842
# RT @sunandasaxena: Great Jai Siya Ram 🙏
# Awesome view
# Wishing everyone love and peace for #Diwali2022
#
#
# Comments:
#
# No Comments
#
# Data 20
# 1584068328083320832
# @AskAnshul Anshul Bhai yeh Pakistan ka nahi hay hamara desh ka hay https://t.co/lwAtg9ZAk8
#
#
# Comments:
#
# 100% [..............................................................................] 43855 / 43855
# Data 21
# 1584068310823743488
# @NerdBuddha @AskAnshul Fake !$I@mik news
#
#
# Comments:
#
#
# Data 22
# 1584068294088093698
# RT @AskAnshul: Black Day #PakRaiders1947
#
# 22 October 1947: Pakistan Army launched ‘Operation Gulmarg’ to snatch J&amp;K
#
# 20 Lashkars (tribal mi…
#
#
# Comments:
#
# No Comments
#
# Data 23
# 1584068262207553536
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 24
# 1584068210047188993
# RT @AskAnshul: Now, The Bell House deleted tweet
#
# Diwali party organised to raise funds for Pakistan, proceeds go to Alkhidmat Foundation…
#
#
# Comments:
#
# No Comments
#
# Data 25
# 1584068202048663553
# RT @AskAnshul: Black Day #PakRaiders1947
#
# 22 October 1947: Pakistan Army launched ‘Operation Gulmarg’ to snatch J&amp;K
#
# 20 Lashkars (tribal mi…
#
#
# Comments:
#
# No Comments
#
# Data 26
# 1584068171555688449
# @NullPointerNone @AskAnshul 365 days there is elections in india
#
#
# Comments:
#
#
# Data 27
# 1584068128509956096
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 28
# 1584068122696613890
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 29
# 1584068119361748993
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 30
# 1584068066291220480
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 31
# 1584068051212722178
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 32
# 1584067927439216640
# RT @MervynLasrado: @drunkJournalist @AskAnshul @rishibagree hey hate mongers, where are y’all? Don’t y’all wanna tweet anything about this?
#
#
# Comments:
#
# No Comments
#
# Data 33
# 1584067886233944065
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 34
# 1584067879967727616
# Under the supervision of a friendly sarkar! https://t.co/JRTaEzkTWt
#
#
# Comments:
#
# No Comments
#
# Data 35
# 1584067835999191042
# RT @AskAnshul: Black Day #PakRaiders1947
#
# 22 October 1947: Pakistan Army launched ‘Operation Gulmarg’ to snatch J&amp;K
#
# 20 Lashkars (tribal mi…
#
#
# Comments:
#
# No Comments
#
# Data 36
# 1584067816159735809
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 37
# 1584067761990701058
# RT @AskAnshul: Indian mathematician &amp; astronomer Aryabhata's bronze bust at the UNESCO Headquarters in Paris. https://t.co/LkYMTNOSxE
#
#
# Comments:
#
# 100% [..............................................................................] 70422 / 70422No Comments
#
# Data 38
# 1584067754373832705
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 39
# 1584067670009606144
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 40
# 1584067662313066496
# RT @AskAnshul: Now, The Bell House deleted tweet
#
# Diwali party organised to raise funds for Pakistan, proceeds go to Alkhidmat Foundation…
#
#
# Comments:
#
# No Comments
#
# Data 41
# 1584067621422772227
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 42
# 1584067595174834183
# @AhmedKhabeer_ He didn't molested her. @AhmedKhabeer_
# @AskAnshul
#
# https://t.co/HoSgAax6kF
#
#
# Comments:
#
#
# Data 43
# 1584067593383837696
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 44
# 1584067575767793664
# @SureshS21753809 @AskAnshul And we know why certain bhakts and their masters are called feku. Actions NOT words. Budget cuts are actions. Words from your masters don't mean shit
# Comments:
#
#
# Data 45
# 1584067563977572352
# @AskAnshul Hey @rakhitripathi look Muslims are being harassed.
# #islamophobia
#
#
# Comments:
#
#
# Data 46
# 1584067554665824256
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 47
# 1584067537620570112
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 48
# 1584067529298702336
# RT @MinorityMjs: పవన్ కళ్యాణ్ గారి ఫ్యామిలీ మీద ఇంతా దారుణంగా మీ వైసీపీ నాయకుడు బోరుగడ్డ అనే వాడు మాట్లాడితే ఎక్కడా ఉన్నావు నువ్వు @padma_v…
#
#
# Comments:
#
# No Comments
#
# Data 49
# 1584067465033977856
# @AskAnshul It's a dream venture of Congress govt which is paying now
#
#
# Comments:
#
#
# Data 50
# 1584067454224912389
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 51
# 1584067451637338117
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 52
# 1584067420674613248
# RT @sunandasaxena: Great Jai Siya Ram 🙏
# Awesome view
# Wishing everyone love and peace for #Diwali2022
#
#
# Comments:
#
# No Comments
#
# Data 53
# 1584067385023090688
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 54
# 1584067284233961472
# RT @AskAnshul: Now, The Bell House deleted tweet
#
# Diwali party organised to raise funds for Pakistan, proceeds go to Alkhidmat Foundation…
#
#
# Comments:
#
# No Comments
#
# Data 55
# 1584067194878840832
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 56
# 1584067170136268800
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 57
# 1584067109327319040
# RT @shalomsureshm: @Starboy2079 @AskAnshul Probably none must have been from his own religion. They work communally every step of their way…
#
#
# Comments:
#
# No Comments
#
# Data 58
# 1584067016117596161
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 59
# 1584066994512416769
# Mini Diwali! https://t.co/Lyf3GtvRzo
#
#
# Comments:
#
# No Comments
#
# Data 60
# 1584066969158168576
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 61
# 1584066949948243968
# RT @sunandasaxena: Great Jai Siya Ram 🙏
# Awesome view
# Wishing everyone love and peace for #Diwali2022
#
#
# Comments:
#
# No Comments
#
# Data 62
# 1584066939147943936
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 63
# 1584066912254066689
# @DOpolitics_in @CPDelhi @DelhiPolice @KapilMishra_IND @UnSubtleDesi @AmitShahOffice @AmarUjalaNews @AmitShah @LtGovDelhi @AskAnshul @AshwiniUpadhyay @
# No FIR , No Judiciary involved....police constables passing judgements and mocking democracy
#
#
# Comments:
#
#
# Data 64
# 1584066822957301760
# RT @AskAnshul: Now, The Bell House deleted tweet
#
# Diwali party organised to raise funds for Pakistan, proceeds go to Alkhidmat Foundation…
#
#
# Comments:
#
# No Comments
#
# Data 65
# 1584066779889836032
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 66
# 1584066727411081217
# @AskAnshul ISRO has forever been our pride!
# Kudos to @isro !
#
#
# Comments:
#
#
# Data 67
# 1584066721144791040
# RT @AskAnshul: Now, The Bell House deleted tweet
#
# Diwali party organised to raise funds for Pakistan, proceeds go to Alkhidmat Foundation…
#
#
# Comments:
#
# No Comments
#
# Data 68
# 1584066677272064000
# RT @AskAnshul: Now, The Bell House deleted tweet
#
# Diwali party organised to raise funds for Pakistan, proceeds go to Alkhidmat Foundation…
#
#
# Comments:
#
# No Comments
#
# Data 69
# 1584066671056416768
# RT @PoliticalEagles: @AskAnshul @APPOLICE100 @NCWIndia @sharmarekha Thousands of such YSRCP Rowdies freely roaming in AP..infact they are t…
#
#
# Comments:
#
# No Comments
#
# Data 70
# 1584066657273925632
# RT @AskAnshul: Black Day #PakRaiders1947
#
# 22 October 1947: Pakistan Army launched ‘Operation Gulmarg’ to snatch J&amp;K
#
# 20 Lashkars (tribal mi…
#
#
# Comments:
#
# No Comments
#
# Data 71
# 1584066593612795904
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 72
# 1584066591892787200
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 73
# 1584066531679698944
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 74
# 1584066528806174720
# RT @AskAnshul: Black Day #PakRaiders1947
#
# 22 October 1947: Pakistan Army launched ‘Operation Gulmarg’ to snatch J&amp;K
#
# 20 Lashkars (tribal mi…
#
#
# Comments:
#
# No Comments
#
# Data 75
# 1584066449827516419
# @vcsvardan1 @AskAnshul @meenaksi050162 Must be busy supporting the scam call centers n their owners who feed $$$ in their pockets🤔🤔
#
#
# Comments:
#
#
# Data 76
# 1584066417812721665
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 77
# 1584066402197024771
# Economy boost #Diwali2022 #INDvsPAK #PakVsInd
# @rajks73
# @navshekhar
# @CS_Reddy_IFS
# @AshishCSamuel
# @INDBureaucracy
# @ReetaMeena5
# @dhananjaysy
# @AmbSanjayPanda
# @HCIMaldives
# @vipulifs
# @AmbKapoor
# @IndembAbuDhabi
# @DineshKPatnaik
# @AmbMunu
# @ambkcsingh
# @AskAnshul
# https://t.co/LVrGVrw1UW
#
#
# Comments:
#
# No Comments
#
# Data 78
# 1584066392751771648
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 79
# 1584066392470409221
# @myogiadityanath @BJP4India @BJP4UP pls hang him 😡😡😡
# @Uppolice when are you taking action??
#
# @KreatelyMedia @OpIndia_com @MumbaichaDon @SureshChavhanke @rishibagree @AskAnshul @NCWIndia @sharmarekha https://t.co/sUYPKAMGKR
#
#
# Comments:
#
# No Comments
#
# Data 80
# 1584066382576365570
# RT @AskAnshul: Now, The Bell House deleted tweet
#
# Diwali party organised to raise funds for Pakistan, proceeds go to Alkhidmat Foundation…
#
#
# Comments:
#
# No Comments
#
# Data 81
# 1584066376872136704
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 82
# 1584066371884789760
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 83
# 1584066348661243904
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 84
# 1584066282370240514
# 🚨 @AskAnshul bhai, see this👇 https://t.co/4ekbaEC0zf
#
#
# Comments:
#
# No Comments
#
# Data 85
# 1584066200790659073
# RT @AskAnshul: Now, The Bell House deleted tweet
#
# Diwali party organised to raise funds for Pakistan, proceeds go to Alkhidmat Foundation…
#
#
# Comments:
#
# No Comments
#
# Data 86
# 1584066177567195136
# RT @AskAnshul: Now, The Bell House deleted tweet
#
# Diwali party organised to raise funds for Pakistan, proceeds go to Alkhidmat Foundation…
#
#
# Comments:
#
# No Comments
#
# Data 87
# 1584066164598386688
# RT @AskAnshul: Now, The Bell House deleted tweet
#
# Diwali party organised to raise funds for Pakistan, proceeds go to Alkhidmat Foundation…
#
#
# Comments:
#
# No Comments
#
# Data 88
# 1584066154221690880
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
# Comments:
#
# No Comments
#
# Data 89
# 1584066132256120833
# RT @AskAnshul: Now, The Bell House deleted tweet
#
# Diwali party organised to raise funds for Pakistan, proceeds go to Alkhidmat Foundation…
#
#
# Comments:
#
# No Comments
#
# Data 90
# 1584066088207151105
# RT @sunandasaxena: Great Jai Siya Ram 🙏
# Awesome view
# Wishing everyone love and peace for #Diwali2022
#
#
# Comments:
#
# No Comments
#
# Data 91
# 1584066066086768641
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 92
# 1584066030586187776
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 93
# 1584065989640998912
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 94
# 1584065929075625984
# RT @AskAnshul: Now, The Bell House deleted tweet
#
# Diwali party organised to raise funds for Pakistan, proceeds go to Alkhidmat Foundation…
#
#
# Comments:
#
# No Comments
#
# Data 95
# 1584065924587323393
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 96
# 1584065906409320448
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 97
# 1584065887782723585
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 98
# 1584065847991357440
# RT @nrajabpcl: @DamodarHegde4 @desai_ujjwala @irajulpandya @nrajabpcla @sreeramjvc @dauntingsh @GauravModified @SanjivMehra8 @Dr_MR_Satapat…
#
#
# Comments:
#
# No Comments
#
# Data 99
# 1584065819444940800
# RT @AskAnshul: ISRO successfully placed 36 OneWeb satellites into orbit in its first commercial mission.
#
# OneWeb is building a space-based…
#
#
# Comments:
#
# No Comments
#
# Data 100
# 1584065816680857600
# RT @AskAnshul: Now, The Bell House deleted tweet
#
# Diwali party organised to raise funds for Pakistan, proceeds go to Alkhidmat Foundation…
#
#
# Comments:
#
# No Comments
