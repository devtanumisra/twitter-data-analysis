# %%
import requests
import wget

# %%
import tweepy

# %%
# Your app's bearer token can be found under the Authentication Tokens section
# of the Keys and Tokens tab of your app, under the
# Twitter Developer Portal Projects & Apps page at
# https://developer.twitter.com/en/portal/projects-and-apps
bearer_token = "AAAAAAAAAAAAAAAAAAAAABvFhgEAAAAAWxWdLEnp6pZJsYMUYAi%2BvFrM5oY%3DrtKXQDsTRS4fXYn44RofMurkHUiMeKlBNVaoAHgJAkVg8DD0GS"

# Your app's API/consumer key and secret can be found under the Consumer Keys
# section of the Keys and Tokens tab of your app, under the
# Twitter Developer Portal Projects & Apps page at
# https://developer.twitter.com/en/portal/projects-and-apps
consumer_key = "r5DowaN8eoM9r1PgQ2ezR6UoN"
consumer_secret = "Z29vyH4fDqlYIRhFyKBgpGvcdTOCdpAhqvau53qsP9KVAlFlbS"

# Your account's (the app owner's account's) access token and secret for your
# app can be found under the Authentication Tokens section of the
# Keys and Tokens tab of your app, under the
# Twitter Developer Portal Projects & Apps page at
# https://developer.twitter.com/en/portal/projects-and-apps
access_token = "1576162990247682049-EsSWVFhd5Z3DrXFZiDkHpN57eRTGXu"
access_token_secret = "qAExjQzAHHkf4FN1LAfZHGocw2E98djMZvmNvEskJQRyr"

# %%
# You can authenticate as your app with just your bearer token
client = tweepy.Client(bearer_token=bearer_token)

# %%
# If the authentication was successful, this should print the
# screen name / username of the account
print(client)
# Out:
# <tweepy.client.Client object at 0x000001A5E7516CA0>

# %% [markdown]
# ## OPEN A CSV FILE AND WRITE THE RESPONSE TO IT

# %%
import csv

# %%
def getComments(id):
    api="https://api.twitter.com/2/tweets/search/recent?query=conversation_id:" + str(id) + "&tweet.fields=in_reply_to_user_id,author_id,created_at,conversation_id"
    response = requests.get(api,headers={"Authorization":"Bearer AAAAAAAAAAAAAAAAAAAAAEnThwEAAAAAO1yTEzATZBIFaa6R7lw8TH7bK3U%3DXswu28WNIUXOUnucNkz7AA0y4U9qxyzBHxsPEs3eDrC3WLmm9o"})
    #print(response.json())
    return response

# %%
def getImageURL(id):
    api="https://api.twitter.com/2/tweets?ids="+ str(id) +"&expansions=attachments.media_keys&media.fields=duration_ms,height,media_key,preview_image_url,public_metrics,type,url,width,alt_text"
    response = requests.get(api,headers={"Authorization":"Bearer AAAAAAAAAAAAAAAAAAAAAEnThwEAAAAAO1yTEzATZBIFaa6R7lw8TH7bK3U%3DXswu28WNIUXOUnucNkz7AA0y4U9qxyzBHxsPEs3eDrC3WLmm9o"})
    str1 = None
    if 'includes'in response.json():
        if 'url'in response.json()['includes']['media'][0]:
            str1 = str(response.json()['includes']['media'][0]['url'])
        elif 'preview_image_url'in response.json()['includes']['media'][0]:
            str1 = str(response.json()['includes']['media'][0]['preview_image_url'])
    return str1

# %%
def downloadImage(url):
    file_name = wget.download(url)
    return file_name

# %%
def getPosts(response,writer):
    data = response.data
    t=0
    for trump in data:
        t+=1
        print()
        print("Data",t)
        print(trump.id)
        print(trump.text)
        st = trump.text
        index = st.rfind("https")
        
        print('\n')
    
        #api ="https://api.twitter.com/2/tweets/search/recent?query=conversation_id:" + str(trump.id) + "&tweet.fields=in_reply_to_user_id,author_id,created_at,conversation_id"
        res = getConversationId(trump.id)
        #print("Comments!!",t)
        conversation_id = res.json()['data'][0]['conversation_id']
        
        print('Comments:\n')
        res = getComments(conversation_id)
        
        imageURL = getImageURL(trump.id)
        file = ''
        
        if imageURL:
            imageFile = downloadImage(imageURL)
            file = imageFile
            
        
        post_row = ["P:"+str(trump.id), '', file, trump.text, 'Caption', "NA" if (index == -1) else st[index:], '', '', '', '', '', '']
        writer.writerow(post_row)
                 
        
        if 'data' not in res.json():
            print("No Comments")
        else:
            #print(res.json())
            for data in res.json()['data']:
                #print(data['text'])
                cmnt_row = ["P:"+str(trump.id), '', '', data['text'], 'Additional Comment','NA', '', '', '', '', '', '']
                writer.writerow(cmnt_row)

# %%
def getConversationId(id):
    api = "https://api.twitter.com/2/tweets?ids=" + str(id) + "&tweet.fields=author_id,conversation_id,created_at,in_reply_to_user_id,referenced_tweets&expansions=author_id,in_reply_to_user_id,referenced_tweets.id&user.fields=name,username"
    response = requests.get(api,headers={"Authorization":"Bearer AAAAAAAAAAAAAAAAAAAAAEnThwEAAAAAO1yTEzATZBIFaa6R7lw8TH7bK3U%3DXswu28WNIUXOUnucNkz7AA0y4U9qxyzBHxsPEs3eDrC3WLmm9o"})
    #print(response.json())
    return response

# %%
f = open('imVkohli.csv', 'w', encoding='UTF16',newline='')
writer = csv.writer(f)

#Insert header into csv file
header = ['POST_ID','POST_LINK','IMAGES_ID','Text','Text Type', 'MEDIA_URL', 'Text OCR', 'Language of Text','Hate Speech','Profane','Sentiment','Targeted Insult']
writer.writerow(header)

response = client.search_recent_tweets("imVkohli", max_results=100)
getPosts(response,writer)
#print(response)
f.close()
# Out:
# Data 1
# 1587287433925705728
# Now is an #opportunity to own real physical #assets from "83" Movie along with snippets from the movie. Re live your "cricket" "dream" #phygital #nfts #NFTIndia #NonFungibleTokens #web3 #metaverse
# Launching Soon !!!! at https://t.co/7TFotUG4ax @akshayaNFT
# https://t.co/KIezlGh79K https://t.co/4iVLRjtrTX
#
#
# Comments:
#
# No Comments
#
# Data 2
# 1587287425532895237
# I bet you can not scroll down without liking this pic.
#
# @imVkohli 🐐💙 https://t.co/T7IvvwirLy
#
#
# Comments:
#
# 100% [............................................................................] 121716 / 121716No Comments
#
# Data 3
# 1587287406755336193
# @imVkohli is the world's best batsman
# Nobody can replace him.... If you are the true fans of #ViratKohli𓃵 retweet and like ❤
# #T20WorldCup2022 #India #IndianCricketTeam https://t.co/KHsYNyye8z
#
#
# Comments:
#
# 100% [..............................................................................] 40977 / 40977No Comments
#
# Data 4
# 1587287401172385792
# @mr_lovely47 @imVkohli @ViratGang @TeamVirat @Cricketracker @cricketpakcompk @BBCSport @BBCWorld Wonderful art❤️❤️hope virat will recognise😍
#
#
# Comments:
#
#
# Data 5
# 1587287397447999488
# RT @Trend_VKohli: The Craze of Virat Kohli is unreal.
# @imVkohli
#
# #ViratKohli | #ViratKohli𓃵 | #T20WorldCup
# https://t.co/jJLKwqon6s
#
#
# Comments:
#
# 100% [..............................................................................] 36214 / 36214No Comments
#
# Data 6
# 1587287379999883265
# RT @Cricketracker: Cute ☺️
#
# @imVkohli | #T20WorldCup2022 | #T20WorldCup
#
# https://t.co/VGINzdRtYS
#
#
# Comments:
#
# 100% [..............................................................................] 36214 / 36214No Comments
#
# Data 7
# 1587287378086879233
# RT @imVkohli: Touchdown Adelaide 🇮🇳🫶 https://t.co/1leNe0jN8L
#
#
# Comments:
#
# 100% [............................................................................] 169523 / 169523No Comments
#
# Data 8
# 1587287356981145600
# RT @VkGnana: Advance Happy birthday anna @imVkohli ❤️ https://t.co/HndStukfEg
#
#
# Comments:
#
# 100% [..............................................................................] 57693 / 57693No Comments
#
# Data 9
# 1587287353709809665
# RT @imVkohli: Touchdown Adelaide 🇮🇳🫶 https://t.co/1leNe0jN8L
#
#
# Comments:
#
# 100% [............................................................................] 169523 / 169523No Comments
#
# Data 10
# 1587287322445238274
# RT @mdsirajofficial: Brothers 🇮🇳 #Adelaide
#
#
# Comments:
#
# No Comments
#
# Data 11
# 1587287302606245888
# RT @Cricketracker: Cute ☺️
#
# @imVkohli | #T20WorldCup2022 | #T20WorldCup
#
# https://t.co/VGINzdRtYS
#
#
# Comments:
#
# 100% [..............................................................................] 36214 / 36214No Comments
#
# Data 12
# 1587287279122644993
# RT @imVkohli: Touchdown Adelaide 🇮🇳🫶 https://t.co/1leNe0jN8L
#
#
# Comments:
#
# 100% [............................................................................] 169523 / 169523No Comments
#
# Data 13
# 1587287269345755136
# RT @imVkohli: Touchdown Adelaide 🇮🇳🫶 https://t.co/1leNe0jN8L
#
#
# Comments:
#
# 100% [............................................................................] 169523 / 169523No Comments
#
# Data 14
# 1587287255214800897
# I'm not your couch
# I'm a your Fan
# suggestion is not a right word
# I'm just asking you
# can team works on Ground fielding
# thrwdown practice
# Save some precious Runs
#
# @BCCI @imVkohli @yuzi_chahal @mdsirajofficial @RishabhPant17 @ashwinravi99 @klrahul @surya_14kumar @hardikpandya7 https://t.co/ivzNU3vGFz
#
#
# Comments:
#
# 100% [..............................................................................] 64230 / 64230No Comments
#
# Data 15
# 1587287253730082816
# @fastcummer_ @Jiten03190559 @tahirmushtaq225 @umran_malik_01 @imVkohli https://t.co/RfhpRvAsYc
#
#
# Comments:
#
# 100% [..............................................................................] 13127 / 13127
# Data 16
# 1587287232527810561
# RT @imVkohli: Tough day today but we focus on the next one. ✌️🇮🇳 https://t.co/REJKpvx82y
#
#
# Comments:
#
# 100% [............................................................................] 162443 / 162443No Comments
#
# Data 17
# 1587287225934680064
# RT @surya_14kumar: 💪😊
#
#
# Comments:
#
# No Comments
#
# Data 18
# 1587287224034684928
# @im_Ritoj @imVkohli Good morning Bhai ❤️
#
#
# Comments:
#
#
# Data 19
# 1587287219022467072
# RT @imVkohli: Touchdown Adelaide 🇮🇳🫶 https://t.co/1leNe0jN8L
#
#
# Comments:
#
# 100% [............................................................................] 169523 / 169523No Comments
#
# Data 20
# 1587287191902117888
# King kohli cover drive six 😮😮
#
# @imVkohli #ViratKohli𓃵 #ViratKohli #Virat #ViratKohliroom #T20WC2022 #T20WorldCup2022 #BCCI https://t.co/iyZntVlv43
#
#
# Comments:
#
# 100% [..............................................................................] 95120 / 95120No Comments
#
# Data 21
# 1587287128928833536
# RT @Cricketracker: Cute ☺️
#
# @imVkohli | #T20WorldCup2022 | #T20WorldCup
#
# https://t.co/VGINzdRtYS
#
#
# Comments:
#
# 100% [..............................................................................] 36214 / 36214No Comments
#
# Data 22
# 1587287127204986880
# @_imperfect_vinu @RVCJ_FB @imVkohli Han tbhi Messi or Rolando k bad isi ka naam ata h most fan following me
#
#
# Comments:
#
#
# Data 23
# 1587287081276932097
# RT @imVkohli: Touchdown Adelaide 🇮🇳🫶 https://t.co/1leNe0jN8L
#
#
# Comments:
#
# 100% [............................................................................] 169523 / 169523No Comments
#
# Data 24
# 1587287050176241665
# @imVkohli My Elder son made your RANGOLI on occasion of Diwali  and WINNING match over Pakistan  have you seen
#
#
# Comments:
#
# No Comments
#
# Data 25
# 1587287048087490560
# Good Morning Everyone 💙🤍❤️😌🙌.
# .
# .
# @imVkohli #ViratKohli𓃵 #KingKohli #CricketTwitter https://t.co/ZvZHksyGoP
#
#
# Comments:
#
# 100% [..............................................................................] 56880 / 56880
# Data 26
# 1587287033692966912
# RT @imVkohli: Tough day today but we focus on the next one. ✌️🇮🇳 https://t.co/REJKpvx82y
#
#
# Comments:
#
# 100% [............................................................................] 162443 / 162443No Comments
#
# Data 27
# 1587287022296629249
# @Kohlis_Girl @imVkohli @ShyamPalla3
#
#
# Comments:
#
#
# Data 28
# 1587287022167023616
# RT @imVkohli: Tough day today but we focus on the next one. ✌️🇮🇳 https://t.co/REJKpvx82y
#
#
# Comments:
#
# 100% [............................................................................] 162443 / 162443No Comments
#
# Data 29
# 1587286998586314752
# RT @imVkohli: Special win. Thank you to all our fans for turning up in numbers. 🇮🇳💙 https://t.co/hAcbuYGa1H
#
#
# Comments:
#
# 100% [............................................................................] 187378 / 187378No Comments
#
# Data 30
# 1587286993142448128
# RT @imVkohli: Touchdown Adelaide 🇮🇳🫶 https://t.co/1leNe0jN8L
#
#
# Comments:
#
# 100% [............................................................................] 169523 / 169523No Comments
#
# Data 31
# 1587286960984293376
# RT @Akhilrc18_: King @imVkohli 👑🙏 https://t.co/8uGL8QvuSp
#
#
# Comments:
#
# 100% [............................................................................] 138632 / 138632No Comments
#
# Data 32
# 1587286957952241665
# RT @RCBTweets: #OnThisDay in 2017, @imVkohli completed 9000 ODI runs in 194 innings, making him the fastest to unlock this achievement. 🙌…
#
#
# Comments:
#
# No Comments
#
# Data 33
# 1587286947483058178
# RT @Trend_VKohli: The Craze of Virat Kohli is unreal.
# @imVkohli
#
# #ViratKohli | #ViratKohli𓃵 | #T20WorldCup
# https://t.co/jJLKwqon6s
#
#
# Comments:
#
# 100% [..............................................................................] 36214 / 36214No Comments
#
# Data 34
# 1587286931310014465
# RT @mdsirajofficial: Brothers 🇮🇳 #Adelaide
#
#
# Comments:
#
# No Comments
#
# Data 35
# 1587286930311487490
# RT @imVkohli: Touchdown Adelaide 🇮🇳🫶 https://t.co/1leNe0jN8L
#
#
# Comments:
#
# 100% [............................................................................] 169523 / 169523No Comments
#
# Data 36
# 1587286920828166144
# RT @hShigri1: What the fuck @imVkohli
#
#
# Comments:
#
# No Comments
#
# Data 37
# 1587286918869680129
# RT @imVkohli: Touchdown Adelaide 🇮🇳🫶 https://t.co/1leNe0jN8L
#
#
# Comments:
#
# 100% [............................................................................] 169523 / 169523No Comments
#
# Data 38
# 1587286911248257025
# @ICC @cricketworldcup @imVkohli @RohitSharma_FC @BCCI क्या ईशान किशन और संजू सैमसन कार्तिक के चोटिल होने के बाद ऋषभ पंत की जगह ले सकते थे क्योंकि दोनों के एल राहुल की खराब फॉर्म के चलते ओपनिंग विकल्प के साथ फिनिशर भी हो सकते थे !!!
# Comments:
#
# No Comments
#
# Data 39
# 1587286909478653952
# RT @Tarakohli_: Finally King's Birthday Month Arrived✌️🍰🥳
# @imVkohli | #ViratKohli https://t.co/9WdKjHjG6K
#
#
# Comments:
#
# 100% [..............................................................................] 57462 / 57462No Comments
#
# Data 40
# 1587286874078388224
# @imVkohli All the best....
#
#
# Comments:
#
#
# Data 41
# 1587286863144194058
# RT @Trend_VKohli: The Craze of Virat Kohli is unreal.
# @imVkohli
#
# #ViratKohli | #ViratKohli𓃵 | #T20WorldCup
# https://t.co/jJLKwqon6s
#
#
# Comments:
#
# 100% [..............................................................................] 36214 / 36214No Comments
#
# Data 42
# 1587286859994255360
# RT @Cricketracker: Cute ☺️
#
# @imVkohli | #T20WorldCup2022 | #T20WorldCup
#
# https://t.co/VGINzdRtYS
#
#
# Comments:
#
# 100% [..............................................................................] 36214 / 36214No Comments
#
# Data 43
# 1587286858773340160
# RT @Pankajchawla616: #shameonharyanagov
# @ArvindKejriwal
# @aajtak
# @SonuSood
# @ndtv
# @imVkohli
# @cmohry
# @PMOIndia https://t.co/Prb6IIjB1v
#
#
# Comments:
#
# 100% [............................................................................] 162334 / 162334No Comments
#
# Data 44
# 1587286834765516800
# RT @Gautham_Karthik: Now this #Diwali becomes even more special! What a chase by the King @imVkohli and @hardikpandya7 👏🏻
#
# Happy Diwali fol…
#
#
# Comments:
#
# No Comments
#
# Data 45
# 1587286834660274176
# RT @Kohlis_Girl: Need more @imVkohli fans on my TL❤️
#
# Mention Your id and retweet.
# I'll follow you all back.. 🖤 https://t.co/wI6bFVmJri
#
#
# Comments:
#
# 100% [............................................................................] 130298 / 130298No Comments
#
# Data 46
# 1587286828889305089
# RT @imVkohli: Touchdown Adelaide 🇮🇳🫶 https://t.co/1leNe0jN8L
#
#
# Comments:
#
# 100% [............................................................................] 169523 / 169523No Comments
#
# Data 47
# 1587286778825670656
# @Harshitsingha_ @CricCrazyJohns @imVkohli 😩😩
#
#
# Comments:
#
#
# Data 48
# 1587286724199137281
# RT @imVkohli: Touchdown Adelaide 🇮🇳🫶 https://t.co/1leNe0jN8L
#
#
# Comments:
#
# 100% [............................................................................] 169523 / 169523No Comments
#
# Data 49
# 1587286693522063360
# RT @EduardoMoront14: #LulaYMaduro @DisneyPlus @imVkohli @narendramodi @20thcentury @3gerardpique @jaarreaza @HectoRodriguez @MalditoSader @…
#
#
# Comments:
#
# No Comments
#
# Data 50
# 1587286685125337093
# RT @mdsirajofficial: Brothers 🇮🇳 #Adelaide
#
#
# Comments:
#
# No Comments
#
# Data 51
# 1587286633946046464
# RT @imVkohli: Touchdown Adelaide 🇮🇳🫶 https://t.co/1leNe0jN8L
#
#
# Comments:
#
# 100% [............................................................................] 169523 / 169523No Comments
#
# Data 52
# 1587286613482053634
# RT @surya_14kumar: 💪😊
#
#
# Comments:
#
# No Comments
#
# Data 53
# 1587286612580257793
# RT @imVkohli: Touchdown Adelaide 🇮🇳🫶 https://t.co/1leNe0jN8L
#
#
# Comments:
#
# 100% [............................................................................] 169523 / 169523No Comments
#
# Data 54
# 1587286611431411712
# @imVkohli Please team play well and win the world Cup team spirit is very important.
#
#
# Comments:
#
#
# Data 55
# 1587286603910635520
# @imVkohli Oh please team management do not include KL in playing 11 henceforth. He is a human waste just like Rohit. Let any one open the innings but not these punks. Those anyone even if they flop doesn't matter as KL and Rohit anyway come back in the dugout before the score is 20 runs.
#
#
# Comments:
#
#
# Data 56
# 1587286536483020800
# RT @imVkohli: Touchdown Adelaide 🇮🇳🫶 https://t.co/1leNe0jN8L
#
#
# Comments:
#
# 100% [............................................................................] 169523 / 169523No Comments
#
# Data 57
# 1587286506346979329
# RT @imVkohli: Touchdown Adelaide 🇮🇳🫶 https://t.co/1leNe0jN8L
#
#
# Comments:
#
# 100% [............................................................................] 169523 / 169523No Comments
#
# Data 58
# 1587286472440238080
# RT @imVkohli: Touchdown Adelaide 🇮🇳🫶 https://t.co/1leNe0jN8L
#
#
# Comments:
#
# 100% [............................................................................] 169523 / 169523No Comments
#
# Data 59
# 1587286437216415744
# RT @Akhilrc18_: King @imVkohli 👑🙏 https://t.co/8uGL8QvuSp
#
#
# Comments:
#
# 100% [............................................................................] 138632 / 138632No Comments
#
# Data 60
# 1587286411577036800
# RT @imVkohli: Touchdown Adelaide 🇮🇳🫶 https://t.co/1leNe0jN8L
#
#
# Comments:
#
# 100% [............................................................................] 169523 / 169523No Comments
#
# Data 61
# 1587286411182362624
# RT @imVkohli: Touchdown Adelaide 🇮🇳🫶 https://t.co/1leNe0jN8L
#
#
# Comments:
#
# 100% [............................................................................] 169523 / 169523No Comments
#
# Data 62
# 1587286397500768256
# RT @harsha_videos: Advance happy birthday @imVkohli 💥❣️
# #ViratKohli𓃵 https://t.co/tya2314se2
#
#
# Comments:
#
# 100% [............................................................................] 174909 / 174909No Comments
#
# Data 63
# 1587286354634891264
# RT @surya_14kumar: 💪😊
#
#
# Comments:
#
# No Comments
#
# Data 64
# 1587286348075266048
# RT @Cricketracker: Cute ☺️
#
# @imVkohli | #T20WorldCup2022 | #T20WorldCup
#
# https://t.co/VGINzdRtYS
#
#
# Comments:
#
# 100% [..............................................................................] 36214 / 36214No Comments
#
# Data 65
# 1587286332950257664
# RT @imVkohli: Tough day today but we focus on the next one. ✌️🇮🇳 https://t.co/REJKpvx82y
#
#
# Comments:
#
# 100% [............................................................................] 162443 / 162443No Comments
#
# Data 66
# 1587286313690013697
# RT @imVkohli: Touchdown Adelaide 🇮🇳🫶 https://t.co/1leNe0jN8L
#
#
# Comments:
#
# 100% [............................................................................] 169523 / 169523No Comments
#
# Data 67
# 1587286309584130048
# RT @Trend_VKohli: The Craze of Virat Kohli is unreal.
# @imVkohli
#
# #ViratKohli | #ViratKohli𓃵 | #T20WorldCup
# https://t.co/jJLKwqon6s
#
#
# Comments:
#
# 100% [..............................................................................] 36214 / 36214No Comments
#
# Data 68
# 1587286262360072194
# RT @imVkohli: Touchdown Adelaide 🇮🇳🫶 https://t.co/1leNe0jN8L
#
#
# Comments:
#
# 100% [............................................................................] 169523 / 169523No Comments
#
# Data 69
# 1587286242328465409
# RT @ViratGang: Virat Kohli's Selfie With A Fan At @AdelaideAirport 🤳🏼
#
# @imVkohli • #T20WorldCup • #ViratGang https://t.co/vGom7Z9cZ2
#
#
# Comments:
#
# 100% [............................................................................] 173926 / 173926No Comments
#
# Data 70
# 1587286160946368512
# RT @imVkohli: Tough day today but we focus on the next one. ✌️🇮🇳 https://t.co/REJKpvx82y
#
#
# Comments:
#
# 100% [............................................................................] 162443 / 162443No Comments
#
# Data 71
# 1587286146144301057
# RT @Trend_VKohli: The Craze of Virat Kohli is unreal.
# @imVkohli
#
# #ViratKohli | #ViratKohli𓃵 | #T20WorldCup
# https://t.co/jJLKwqon6s
#
#
# Comments:
#
# 100% [..............................................................................] 36214 / 36214No Comments
#
# Data 72
# 1587286139169374209
# @imVkohli plz...save me my friend Kohli sir https://t.co/ZuT8sWvbKK
#
#
# Comments:
#
# 100% [..............................................................................] 39697 / 39697No Comments
#
# Data 73
# 1587286055060836353
# RT @imVkohli: Touchdown Adelaide 🇮🇳🫶 https://t.co/1leNe0jN8L
#
#
# Comments:
#
# 100% [............................................................................] 169523 / 169523No Comments
#
# Data 74
# 1587285992825913344
# @imVkohli Indians you are not worthy of hope  South Africa I knew you didn't win
#
#
# Comments:
#
# No Comments
#
# Data 75
# 1587285941592674304
# RT @KohliSensation: Touchdown Adelaide 🇮🇳🫶🏻
#
# #TeamIndia #T20WorldCup @imVkohli https://t.co/OcgMdDgg00
#
#
# Comments:
#
# 100% [............................................................................] 169523 / 169523No Comments
#
# Data 76
# 1587285932096761856
# Sneak in @imVkohli
# #HotelRoom
# Shared video by him himself ..
# Do watch @CricketAus
# @BCCI
# @AnushkaSharma
#
# https://t.co/6YKKauKe2B
#
#
# Comments:
#
# No Comments
#
# Data 77
# 1587285929605013506
# RT @imVkohli: Touchdown Adelaide 🇮🇳🫶 https://t.co/1leNe0jN8L
# Comments:
#
# 100% [............................................................................] 169523 / 169523No Comments
#
# Data 78
# 1587285911435640833
# RT @imVkohli: Touchdown Adelaide 🇮🇳🫶 https://t.co/1leNe0jN8L
#
#
# Comments:
#
# 100% [............................................................................] 169523 / 169523No Comments
#
# Data 79
# 1587285863079477248
# RT @Trend_VKohli: The Craze of Virat Kohli is unreal.
# @imVkohli
#
# #ViratKohli | #ViratKohli𓃵 | #T20WorldCup
# https://t.co/jJLKwqon6s
#
#
# Comments:
#
# 100% [..............................................................................] 36214 / 36214No Comments
#
# Data 80
# 1587285833001811969
# RT @surya_14kumar: 💪😊
#
#
# Comments:
#
# No Comments
#
# Data 81
# 1587285831332823041
# RT @imVkohli: Touchdown Adelaide 🇮🇳🫶 https://t.co/1leNe0jN8L
#
#
# Comments:
#
# 100% [............................................................................] 169523 / 169523No Comments
#
# Data 82
# 1587285824428654592
# RT @imVkohli: Touchdown Adelaide 🇮🇳🫶 https://t.co/1leNe0jN8L
#
#
# Comments:
#
# 100% [............................................................................] 169523 / 169523No Comments
#
# Data 83
# 1587285811187265537
# RT @Cricketracker: Cute ☺️
#
# @imVkohli | #T20WorldCup2022 | #T20WorldCup
#
# https://t.co/VGINzdRtYS
#
#
# Comments:
#
# 100% [..............................................................................] 36214 / 36214No Comments
#
# Data 84
# 1587285802903425024
# Virat Kohli's Selfie With A Fan At @AdelaideAirport 🤳🏼
#
# @imVkohli • #T20WorldCup • #ViratGang https://t.co/vGom7Z9cZ2
#
#
# Comments:
#
# 100% [............................................................................] 173926 / 173926No Comments
#
# Data 85
# 1587285753939181568
# @noway_rio @imVkohli Are Mera bhi b'day hai november me 😅😝
#
#
# Comments:
#
#
# Data 86
# 1587285725493399552
# RT @imVkohli: Touchdown Adelaide 🇮🇳🫶 https://t.co/1leNe0jN8L
#
#
# Comments:
#
# 100% [............................................................................] 169523 / 169523No Comments
#
# Data 87
# 1587285677020155905
# @imVkohli Best.  Wishes.   Team. India   We love. U all👍👍
#
#
# Comments:
#
#
# Data 88
# 1587285609772511233
# @imVkohli Sir piz help me 😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭
#
#
# Comments:
#
#
# Data 89
# 1587285577677799424
# RT @imVkohli: Touchdown Adelaide 🇮🇳🫶 https://t.co/1leNe0jN8L
#
#
# Comments:
#
# 100% [............................................................................] 169523 / 169523No Comments
#
# Data 90
# 1587285514016522240
# RT @imVkohli: Touchdown Adelaide 🇮🇳🫶 https://t.co/1leNe0jN8L
#
#
# Comments:
#
# 100% [............................................................................] 169523 / 169523No Comments
#
# Data 91
# 1587285457330524160
# RT @PureKohli18: World's Fastest Thing Is Virat Kohli's Cover Drive.
#
# @imVkohli 🐐 https://t.co/0pkKLE4VcP
#
#
# Comments:
#
# 100% [..............................................................................] 67309 / 67309No Comments
#
# Data 92
# 1587285429770162178
# @Esha963 @imVkohli Abbe pahle apne Babar Ko khelna Sikha tu 😅
#
#
# Comments:
#
#
# Data 93
# 1587285409247002624
# RT @imVkohli: Special win. Thank you to all our fans for turning up in numbers. 🇮🇳💙 https://t.co/hAcbuYGa1H
#
#
# Comments:
#
# 100% [............................................................................] 187378 / 187378No Comments
#
# Data 94
# 1587285399184941057
# @imVkohli Good morning sir
#
#
# Comments:
#
#
# Data 95
# 1587285348379684864
# Cheap tricks from Australia hotel room where Kohli is staying. You can't divert his dedication from #ICCT20WorldCup2022. Experience the batting  master in coming games from the bat of Virat @imVkohli
#
#
# Comments:
#
# No Comments
#
# Data 96
# 1587285307539324928
# RT @imVkohli: Touchdown Adelaide 🇮🇳🫶 https://t.co/1leNe0jN8L
#
#
# Comments:
#
# 100% [............................................................................] 169523 / 169523No Comments
#
# Data 97
# 1587285292452835328
# RT @RCBTweets: The #MenInBlue have arrived and the plans have been ADELAIDE out! 💪
#
#
# Comments:
#
# No Comments
#
# Data 98
# 1587285266305142784
# @Ishtiaqhussainn @imVkohli Tumhara match v hai bangalyo se chutiye.... Zimbabwe se to Jeet nhi paye
#
#
# Comments:
#
#
# Data 99
# 1587285265005318145
# RT @Esha963: @imVkohli Dear Duckrat Afgholi Plzzz Sir Chashma Laga Kar Khela Karain 🙏 tumhare Chashma na lagane ki Waja se Hum tournament s…
#
#
# Comments:
#
# No Comments
#
# Data 100
# 1587285232956628992
# RT @Ravikantp0405: #51000_MPTET_VARG_3
# #NO_Vacancy_NO_Vote
# शौक–
# @imVkohli को क्रिकेट
# @Cristiano को फुटबाल
# @DrKumarVishwas को कविता
# @SrBach…
#
#
# Comments:
#
# No Comments
