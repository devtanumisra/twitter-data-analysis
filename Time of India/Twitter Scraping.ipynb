# %%
import requests
import wget

# %%
import tweepy

# %%
# Your app's bearer token can be found under the Authentication Tokens section
# of the Keys and Tokens tab of your app, under the
# Twitter Developer Portal Projects & Apps page at
# https://developer.twitter.com/en/portal/projects-and-apps
bearer_token = "AAAAAAAAAAAAAAAAAAAAABvFhgEAAAAAWxWdLEnp6pZJsYMUYAi%2BvFrM5oY%3DrtKXQDsTRS4fXYn44RofMurkHUiMeKlBNVaoAHgJAkVg8DD0GS"

# Your app's API/consumer key and secret can be found under the Consumer Keys
# section of the Keys and Tokens tab of your app, under the
# Twitter Developer Portal Projects & Apps page at
# https://developer.twitter.com/en/portal/projects-and-apps
consumer_key = "r5DowaN8eoM9r1PgQ2ezR6UoN"
consumer_secret = "Z29vyH4fDqlYIRhFyKBgpGvcdTOCdpAhqvau53qsP9KVAlFlbS"

# Your account's (the app owner's account's) access token and secret for your
# app can be found under the Authentication Tokens section of the
# Keys and Tokens tab of your app, under the
# Twitter Developer Portal Projects & Apps page at
# https://developer.twitter.com/en/portal/projects-and-apps
access_token = "1576162990247682049-EsSWVFhd5Z3DrXFZiDkHpN57eRTGXu"
access_token_secret = "qAExjQzAHHkf4FN1LAfZHGocw2E98djMZvmNvEskJQRyr"

# %%
# You can authenticate as your app with just your bearer token
client = tweepy.Client(bearer_token=bearer_token)

# %%
# If the authentication was successful, this should print the
# screen name / username of the account
print(client)
# Out:
# <tweepy.client.Client object at 0x000001DD0B927850>

# %% [markdown]
# ## OPEN A CSV FILE AND WRITE THE RESPONSE TO IT

# %%
import csv

# %%
def getComments(id):
    api="https://api.twitter.com/2/tweets/search/recent?query=conversation_id:" + str(id) + "&tweet.fields=in_reply_to_user_id,author_id,created_at,conversation_id"
    response = requests.get(api,headers={"Authorization":"Bearer AAAAAAAAAAAAAAAAAAAAAEnThwEAAAAAO1yTEzATZBIFaa6R7lw8TH7bK3U%3DXswu28WNIUXOUnucNkz7AA0y4U9qxyzBHxsPEs3eDrC3WLmm9o"})
    #print(response.json())
    return response

# %%
def getImageURL(id):
    api="https://api.twitter.com/2/tweets?ids="+ str(id) +"&expansions=attachments.media_keys&media.fields=duration_ms,height,media_key,preview_image_url,public_metrics,type,url,width,alt_text"
    response = requests.get(api,headers={"Authorization":"Bearer AAAAAAAAAAAAAAAAAAAAAEnThwEAAAAAO1yTEzATZBIFaa6R7lw8TH7bK3U%3DXswu28WNIUXOUnucNkz7AA0y4U9qxyzBHxsPEs3eDrC3WLmm9o"})
    str1 = None
    if 'includes'in response.json():
        if 'url'in response.json()['includes']['media'][0]:
            str1 = str(response.json()['includes']['media'][0]['url'])
        elif 'preview_image_url'in response.json()['includes']['media'][0]:
            str1 = str(response.json()['includes']['media'][0]['preview_image_url'])
    return str1

# %%
def downloadImage(url):
    file_name = wget.download(url)
    return file_name

# %%
def getPosts(response,writer):
    data = response.data
    t=0
    for trump in data:
        t+=1
        print()
        print("Data",t)
        print(trump.id)
        print(trump.text)
        st = trump.text
        index = st.rfind("https")
        
        print('\n')
    
        #api ="https://api.twitter.com/2/tweets/search/recent?query=conversation_id:" + str(trump.id) + "&tweet.fields=in_reply_to_user_id,author_id,created_at,conversation_id"
        res = getConversationId(trump.id)
        #print("Comments!!",t)
        conversation_id = res.json()['data'][0]['conversation_id']
        
        print('Comments:\n')
        res = getComments(conversation_id)
        
        imageURL = getImageURL(trump.id)
        file = ''
        
        if imageURL:
            imageFile = downloadImage(imageURL)
            file = imageFile
            
        
        post_row = ["P:"+str(trump.id), '', file, trump.text, 'Caption', imageURL, '', '', '', '', '', '']
        writer.writerow(post_row)
                 
        
        if 'data' not in res.json():
            print("No Comments")
        else:
            #print(res.json())
            for data in res.json()['data']:
                #print(data['text'])
                cmnt_row = ["P:"+str(trump.id), '', '', data['text'], 'Additional Comment','NA', '', '', '', '', '', '']
                writer.writerow(cmnt_row)

# %%
def getConversationId(id):
    api = "https://api.twitter.com/2/tweets?ids=" + str(id) + "&tweet.fields=author_id,conversation_id,created_at,in_reply_to_user_id,referenced_tweets&expansions=author_id,in_reply_to_user_id,referenced_tweets.id&user.fields=name,username"
    response = requests.get(api,headers={"Authorization":"Bearer AAAAAAAAAAAAAAAAAAAAAEnThwEAAAAAO1yTEzATZBIFaa6R7lw8TH7bK3U%3DXswu28WNIUXOUnucNkz7AA0y4U9qxyzBHxsPEs3eDrC3WLmm9o"})
    #print(response.json())
    return response

# %%
f = open('times_of_india.csv', 'w', encoding='UTF8',newline='')
writer = csv.writer(f)

#Insert header into csv file
header = ['POST_ID','POST_LINK','IMAGES_ID','Text','Text Type', 'MEDIA_URL', 'Text OCR', 'Language of Text','Hate Speech','Profane','Sentiment','Targeted Insult']
writer.writerow(header)

response = client.search_recent_tweets("timesofindia", max_results=100)
getPosts(response,writer)
#print(response)
f.close()
# Out:
# Data 1
# 1584054616698028032
# RT @majorgauravarya: ISRO’s heaviest rocket successfully places 36 OneWeb satellites into orbit. LVM3 makes its entry into the global comme…
#
#
# Comments:
#
# No Comments
#
# Data 2
# 1584054613917208576
# Year after Instagram debut, PM clips draw record views
# https://t.co/GNp3EpgtbB via NaMo App https://t.co/ru7Sn0syjQ
#
#
# Comments:
#
# 100% [............................................................................] 145008 / 145008No Comments
#
# Data 3
# 1584054613577445381
# RT @majorgauravarya: ISRO’s heaviest rocket successfully places 36 OneWeb satellites into orbit. LVM3 makes its entry into the global comme…
#
#
# Comments:
#
# No Comments
#
# Data 4
# 1584054608044752896
# RT @Narende01589313: @dichicorp @mlkhattar @DC_Gurugram @MCManesar @dtcphry @kMakrandIAS @diprogurugram1 @DiprHaryana @cmohry @nishantyadav…
#
#
# Comments:
#
# No Comments
#
# Data 5
# 1584054585945051136
# RT @BombagorerRaja: Digha hosted the Bengal Global Business Summit &amp; is aiming for G20 Meetings in Jan 2023. With the Tajpur Port, Digha Ma…
#
#
# Comments:
#
# No Comments
#
# Data 6
# 1584054568031518720
# RT @majorgauravarya: ISRO’s heaviest rocket successfully places 36 OneWeb satellites into orbit. LVM3 makes its entry into the global comme…
#
#
# Comments:
#
# No Comments
#
# Data 7
# 1584054523504766977
# Varanasi: Four robbers of inter-state gang arrested https://t.co/mGUevcC8gK
#
#
# Comments:
#
# No Comments
#
# Data 8
# 1584054516973916160
# RT @ShelarAshish: Spl CBI Court confirms Vaze Vassoli&amp;100 cr/ month extortion was carried out by Uddhavji Govt HM Anil Deshmukh!
# This festi…
#
#
# Comments:
#
# No Comments
#
# Data 9
# 1584054511752151044
# If the Hindu Kush could speak, they would tell us many stories and reveal many secrets, of those who crossed, and those who died, on its treacherous passes and slopes
#
# @devduttmyth
#
# https://t.co/sD1ouxE8cy
#
#
# Comments:
#
# No Comments
#
# Data 10
# 1584054464293400576
# Year after Instagram debut, PM clips draw record views
# https://t.co/cdC5nkjPSY via NaMo App https://t.co/y9A7Slciv1
#
#
# Comments:
#
# 100% [............................................................................] 174743 / 174743No Comments
#
# Data 11
# 1584054437038804992
# @Narende01589313 @dichicorp @mlkhattar @DC_Gurugram @MCManesar @dtcphry @kMakrandIAS @diprogurugram1 @DiprHaryana @cmohry @nishantyadavIAS @reenadhankher1 @jacque_jindal @IndiaAheadNews @timesofindia @ashokkmalik1 @Realty_Et #stepindlfbeforeitstoolate
# #DLFsaveourhomes
# #PoorConstructionByDLF
# @cmohry @dtcphry @kMakrandIAS @mlkhattar @diprogurugram1 @DiprHaryana @DC_Gurugram @nishantyadavIAS
# @reenadhankher1
# @IndiaAheadNews
# @jacque_jindal
# DLF to carryout major structural repairs at their cost
#
#
# Comments:
#
#
# Data 12
# 1584054420878524418
# RT @majorgauravarya: ISRO’s heaviest rocket successfully places 36 OneWeb satellites into orbit. LVM3 makes its entry into the global comme…
#
#
# Comments:
#
# No Comments
#
# Data 13
# 1584054398011207680
# Year after Instagram debut, PM clips draw record views  https://t.co/EK4IZBPl06
#
#
# Comments:
#
# No Comments
#
# Data 14
# 1584054387890323462
# Year after Instagram debut, PM clips draw record views https://t.co/sDt61DaFWb via @timesofindia
#
#
# Comments:
#
# No Comments
#
# Data 15
# 1584054346744201217
# RT @ETimesTV: This adorable video of #KaranKundrra spying on #TejasswiParkash is being loved by fans!
#
# https://t.co/5tpraaAVLZ
#
#
# Comments:
#
# No Comments
#
# Data 16
# 1584054332785569792
# @RURALINDIA https://t.co/AKoOHvf6la.    Probably in National Herald Bank!!
#
#
# Comments:
#
#
# Data 17
# 1584054330868764673
# RT @timesofindia: Smog covers #Delhi sky; overall air quality in 'poor' category
#
# visuals from near #Akshardham temple https://t.co/kxPJY6r…
#
#
# Comments:
#
# No Comments
#
# Data 18
# 1584054329472057346
# RT @TOICitiesNews: Stubble burning remains a 'significant contributor' to Delhi's unbreathable air in October, November: CREA study https:/…
#
#
# Comments:
#
# No Comments
#
# Data 19
# 1584054325885960192
# RT @ETimesTV: The party was attended by not just the who's who of Bollywood but also the television industry
#
# #ShehnaazGiIl #RupaliGanguly…
#
#
# Comments:
#
# No Comments
#
# Data 20
# 1584054311528501250
# RT @Narende01589313: @dichicorp @mlkhattar @DC_Gurugram @MCManesar @dtcphry @kMakrandIAS @diprogurugram1 @DiprHaryana @cmohry @nishantyadav…
#
#
# Comments:
#
# No Comments
#
# Data 21
# 1584054310929043456
# RT @TOICitiesNews: Maharashtra: Thane history-sheeter dies hours after being shot at https://t.co/aKsIZD8wUv
#
#
# Comments:
#
# No Comments
#
# Data 22
# 1584054286149128198
# RT @TOICitiesNews: Punjab: AK-56 rifle recovered on disclosure of RPG attack accused https://t.co/qVQpm55Qtc
#
#
# Comments:
#
# No Comments
#
# Data 23
# 1584054263319121920
# RT @dichicorp: @mlkhattar @DC_Gurugram @MCManesar @dtcphry @kMakrandIAS @diprogurugram1 @DiprHaryana @cmohry @DiprHaryana @nishantyadavIAS…
#
#
# Comments:
#
# No Comments
#
# Data 24
# 1584054220876939264
# @singhesha10 @ChandNawabMisir @PMOIndia @ianuragthakur @KirenRijiju @timesofindia @KTRTRS @TelanganaCMO @jayesh_ranjan @suldeep @Media_SAI @DGSAI Congratulations champion, keep winning and make India proud
#
#
# Comments:
#
#
# Data 25
# 1584054220369498113
# RT @majorgauravarya: ISRO’s heaviest rocket successfully places 36 OneWeb satellites into orbit. LVM3 makes its entry into the global comme…
#
#
# Comments:
#
# No Comments
#
# Data 26
# 1584054203437436929
# RT @TOICitiesNews: 2 robbers held following encounter in Delhi's Jyoti Nagar: Police https://t.co/s677aBecxg
#
#
# Comments:
#
# No Comments
#
# Data 27
# 1584054199582457856
# RT @majorgauravarya: ISRO’s heaviest rocket successfully places 36 OneWeb satellites into orbit. LVM3 makes its entry into the global comme…
#
#
# Comments:
#
# No Comments
#
# Data 28
# 1584054161536348161
# RT @majorgauravarya: ISRO’s heaviest rocket successfully places 36 OneWeb satellites into orbit. LVM3 makes its entry into the global comme…
#
#
# Comments:
#
# No Comments
#
# Data 29
# 1584054160877846529
# RT @TOICitiesNews: Puducherry CB-CID arrests kingpin of overseas employment racket https://t.co/HNh8GACI5a
#
#
# Comments:
#
# No Comments
#
# Data 30
# 1584054148991193088
# RT @sapna19sharma: Corona Berozgar Aspirants
# #UPSCExtraAttempt
# #Unemployed_Youth
# @PMOIndia @narendramodi @ndtvindia @CNNnews18 @timesofin…
#
#
# Comments:
#
# No Comments
#
# Data 31
# 1584054145484353536
# RT @akfromindia: Noida police is reluctant to curb Rash Driving &amp; Wrong side driving. people drive without the fear of law ⁦@CeoNoida⁩ ⁦@no…
#
#
# Comments:
#
# No Comments
#
# Data 32
# 1584054140610936833
# RT @majorgauravarya: ISRO’s heaviest rocket successfully places 36 OneWeb satellites into orbit. LVM3 makes its entry into the global comme…
#
#
# Comments:
#
# No Comments
#
# Data 33
# 1584054136605052928
# @timesofindia Cheap liquor serving at state by govt , may be the reason for this...
#
#
# Comments:
#
#
# Data 34
# 1584054090744860672
# Year after Instagram debut, PM @narendramodi clips draw record views
# https://t.co/nqbHgKepXr via NaMo App https://t.co/8GyERcWRZv
#
#
# Comments:
#
# 100% [............................................................................] 108670 / 108670No Comments
#
# Data 35
# 1584054079319203841
# SO BE PREPARED FOR ANOTHER VIRUS LEAK AND UPSHOTS - https://t.co/8RhaGD20us
#
#
# Comments:
#
# No Comments
#
# Data 36
# 1584054034574774272
# RT @TOICitiesNews: Bihar CM Nitish Kumar launches online transfer of special financial assistance to drought-hit families https://t.co/4t0E…
#
#
# Comments:
#
# No Comments
#
# Data 37
# 1584054030879580162
# RT @Narende01589313: @dichicorp @mlkhattar @DC_Gurugram @MCManesar @dtcphry @kMakrandIAS @diprogurugram1 @DiprHaryana @cmohry @nishantyadav…
#
#
# Comments:
#
# No Comments
#
# Data 38
# 1584054028983754752
# Year after Instagram debut, PM clips draw record views
# https://t.co/1vHYdOpph0 via NaMo App https://t.co/5SGQyBpHDy
#
#
# Comments:
#
# 100% [............................................................................] 118132 / 118132No Comments
#
# Data 39
# 1584054006535462912
# When will they resent their money being spent by Modi on temple tours and pujas?
#
# Kab khaulega re tera khoon? 🤔
# https://t.co/tWWtFm8GJ9
#
#
# Comments:
#
#
# Data 40
# 1584053972985581568
# Year after Instagram debut, PM clips draw record views
# https://t.co/god3sogIOD
#
# via NaMo App https://t.co/ipKmb8Eugk
#
#
# Comments:
#
# 100% [............................................................................] 136400 / 136400No Comments
#
# Data 41
# 1584053970787442688
# RT @dichicorp: @mlkhattar @DC_Gurugram @MCManesar @dtcphry @kMakrandIAS @diprogurugram1 @DiprHaryana @cmohry @DiprHaryana @nishantyadavIAS…
# Comments:
#
# No Comments
#
# Data 42
# 1584053924457107456
# RT @RMofficialmusic: Punjab : Over 90,000 pension beneficiaries found dead in a govt survey.
#
# October 13, 2022.
#
# Link 👇👇👇
#
# https://t.co/pM1…
#
#
# Comments:
#
# No Comments
#
# Data 43
# 1584053897550696448
# Year after Instagram debut, PM clips draw record views
# https://t.co/mtfxzEnhCP via NaMo App https://t.co/x5azPU4J65
#
#
# Comments:
#
# 100% [............................................................................] 144365 / 144365No Comments
#
# Data 44
# 1584053860250763264
# RT @majorgauravarya: ISRO’s heaviest rocket successfully places 36 OneWeb satellites into orbit. LVM3 makes its entry into the global comme…
#
#
# Comments:
#
# No Comments
#
# Data 45
# 1584053842198425600
# #T20WorldCup | #SLvIRE | Super 12
#
# The 18th over ends with a big wicket. Fernando ends Tector's fighting knock of 45.
#
# Ireland 117/6.
#
# #SLvsIRE #HarryTector
#
# FOLLOW LIVE: https://t.co/fDfW9AMEhu https://t.co/VyQo45pCIR
#
#
# Comments:
#
# 100% [............................................................................] 128439 / 128439No Comments
#
# Data 46
# 1584053829481672704
# RT @TOICitiesNews: Bhopal: Joyride in wee hours with friends turns fatal, engineering student dies in sports-bike crash https://t.co/M1C3kO…
#
#
# Comments:
#
# No Comments
#
# Data 47
# 1584053823865491456
# RT @Jackncyberspace: https://t.co/xt8g33vEpQ
#
# Maybe motivation for decriminalizing Adultery Law
# #NotMyCJI #MaleGenocide #LegalGenocide htt…
#
#
# Comments:
#
# No Comments
#
# Data 48
# 1584053823261519873
# @sagarikaghose @INCIndia @ShashiTharoor @PChidambaram_IN @ghulamnazad @timesofindia Sagarika, try anulom vilom....
#
#
# Comments:
#
#
# Data 49
# 1584053820694241280
# RT @majorgauravarya: ISRO’s heaviest rocket successfully places 36 OneWeb satellites into orbit. LVM3 makes its entry into the global comme…
#
#
# Comments:
#
# No Comments
#
# Data 50
# 1584053813949800448
# @sagarikaghose @INCIndia @ShashiTharoor @PChidambaram_IN @ghulamnazad @timesofindia Mam Azad already left do some home work
#
#
# Comments:
#
#
# Data 51
# 1584053810666012674
# Year after Instagram debut, PM clips draw record views
# https://t.co/A7e4cr6oWP
#
# via NaMo App https://t.co/RsKyHxqcTL
#
#
# Comments:
#
# 100% [............................................................................] 157052 / 157052No Comments
#
# Data 52
# 1584053810129154049
# RT @TOICitiesNews: Seven injured in blast at BPCL oil depot near Bhopal https://t.co/HsmV2sw8DF
#
#
# Comments:
#
# No Comments
#
# Data 53
# 1584053799836332033
# RT @TOICitiesNews: Kerala: Biodiversity co-ordination committees to be formed in all districts https://t.co/rnI8mFPWWh
#
#
# Comments:
#
# No Comments
#
# Data 54
# 1584053792789569536
# RT @SuryaNa85488091: @SSPATRA84 @Naveen_Odisha @CMO_Odisha @pranabpdas @GovernorOdisha @gapg_dept @SecyChief @MoSarkar5T @otvnews @kanak_ne…
#
#
# Comments:
#
# No Comments
#
# Data 55
# 1584053780844523520
# Year after Instagram debut, PM clips draw record views
# https://t.co/fhugzYXiId
#
# via NaMo App https://t.co/ZqzpikUXMw
#
#
# Comments:
#
# 100% [............................................................................] 166868 / 166868No Comments
#
# Data 56
# 1584053780274118656
# RT @TOICitiesNews: Worker at firecracker stall dies of electrocution by live wire in Pune https://t.co/lrT8xLEnV6
#
#
# Comments:
#
# No Comments
#
# Data 57
# 1584053769628971013
# RT @TOICitiesNews: Traffic snarls across Delhi as shoppers throng markets on Dhanteras https://t.co/0rqREea8hv
#
#
# Comments:
#
# No Comments
#
# Data 58
# 1584053757666504704
# RT @Narende01589313: @dichicorp @mlkhattar @DC_Gurugram @MCManesar @dtcphry @kMakrandIAS @diprogurugram1 @DiprHaryana @cmohry @nishantyadav…
#
#
# Comments:
#
# No Comments
#
# Data 59
# 1584053750733234178
# Year after Instagram debut, PM clips draw record views
# https://t.co/HM6YJe2tjg via NaMo App https://t.co/nBuxGbY5C9
#
#
# Comments:
#
# 100% [............................................................................] 148770 / 148770No Comments
#
# Data 60
# 1584053749500153857
# RT @DalpatBirendra: @SSPATRA84 @Naveen_Odisha @CMO_Odisha @pranabpdas @GovernorOdisha @gapg_dept @SecyChief @MoSarkar5T @otvnews @kanak_new…
#
#
# Comments:
#
# No Comments
#
# Data 61
# 1584053699621818368
# RT @TOICitiesNews: No fine for flouting traffic rules in Gujarat during Diwali, announces govt; Asaduddin Owaisi calls it 'Revdi' https://t…
#
#
# Comments:
#
# No Comments
#
# Data 62
# 1584053659872022528
# RT @majorgauravarya: ISRO’s heaviest rocket successfully places 36 OneWeb satellites into orbit. LVM3 makes its entry into the global comme…
#
#
# Comments:
#
# No Comments
#
# Data 63
# 1584053638049038336
# RT @majorgauravarya: ISRO’s heaviest rocket successfully places 36 OneWeb satellites into orbit. LVM3 makes its entry into the global comme…
#
#
# Comments:
#
# No Comments
#
# Data 64
# 1584053621137997824
# RT @singhesha10: Concluded my world championship Cairo Egypt 2022 ,3 gold and one bronze 🥇🥇🥇 🥉proud moment with goose bumps putting the fla…
#
#
# Comments:
#
# No Comments
#
# Data 65
# 1584053603224125440
# RT @Jackncyberspace: https://t.co/xt8g33vEpQ
#
# Maybe motivation for decriminalizing Adultery Law
# #NotMyCJI #MaleGenocide #LegalGenocide htt…
#
#
# Comments:
#
# No Comments
#
# Data 66
# 1584053526379888640
# RT @majorgauravarya: ISRO’s heaviest rocket successfully places 36 OneWeb satellites into orbit. LVM3 makes its entry into the global comme…
#
#
# Comments:
#
# No Comments
#
# Data 67
# 1584053495392452608
# RT @majorgauravarya: ISRO’s heaviest rocket successfully places 36 OneWeb satellites into orbit. LVM3 makes its entry into the global comme…
#
#
# Comments:
#
# No Comments
#
# Data 68
# 1584053470381764608
# Year after Instagram debut, PM clips draw record views
# https://t.co/t7QU2ExoJw
#
# via NaMo App https://t.co/YwsGdOua8b
#
#
# Comments:
#
# 100% [............................................................................] 184624 / 184624No Comments
#
# Data 69
# 1584053441302667264
# RT @majorgauravarya: ISRO’s heaviest rocket successfully places 36 OneWeb satellites into orbit. LVM3 makes its entry into the global comme…
#
#
# Comments:
#
# No Comments
#
# Data 70
# 1584053419878551552
# RT @TOICitiesNews: Target of providing 10 lakh jobs will be completed timely: Union minister https://t.co/O4evZNBSw8
#
#
# Comments:
#
# No Comments
#
# Data 71
# 1584053413674766336
# RT @KhirodC71927092: @SSPATRA84 @Naveen_Odisha @CMO_Odisha @pranabpdas @GovernorOdisha @gapg_dept @SecyChief @MoSarkar5T @otvnews @kanak_ne…
#
#
# Comments:
#
# No Comments
#
# Data 72
# 1584053399766503424
# RT @Manisha32204457: @SSPATRA84 @Naveen_Odisha @CMO_Odisha @pranabpdas @GovernorOdisha @gapg_dept @SecyChief @MoSarkar5T @otvnews @kanak_ne…
#
#
# Comments:
#
# No Comments
#
# Data 73
# 1584053399342809090
# Ramya,who recently announced that she would soon be making a comeback with the Raj B Shetty directorial, Swathi Mutthina Male Haniye, has opted out of the project. Siri Ravikumar of Sakutumba Sameta fame will now be stepping into her shoes
# https://t.co/Ij3m8UQVRd
#
#
# Comments:
#
# No Comments
#
# Data 74
# 1584053395048271874
# Hyderabad: Drug peddler held with 30 grams of MDMA https://t.co/jhcCSvWGVZ
#
#
# Comments:
#
# No Comments
#
# Data 75
# 1584053382737965057
# Telugu films #RRR #Akhanda #cinemaBandi and #kudirambose to be screened during #iffi Indian Panorama...!
#
# https://t.co/Nu5KnSUQrD
#
#
# Comments:
#
# No Comments
#
# Data 76
# 1584053378992451584
# Year after Instagram debut, PM @narendramodi ji clips draw record views
# https://t.co/jY3i3Vzpir
#
# via NaMo App https://t.co/pBnD8pVlQ8
#
#
# Comments:
#
# 100% [............................................................................] 172188 / 172188No Comments
#
# Data 77
# 1584053362680483840
# Well said! @PMOIndia
# Taxpayers resent money wasted on freebies: PM Modi https://t.co/w2m03XiVS4 via @timesofindia
#
#
# Comments:
#
# No Comments
#
# Data 78
# 1584053330757578752
# "ELECTED"! IN A COMMI COUNTRY! HA HA HA  - https://t.co/8RhaGD20us
#
#
# Comments:
#
# No Comments
#
# Data 79
# 1584053322792980480
# RT @TOICitiesNews: Happily wherever after: Bride decamps with cash, jewellery day after wedding in Uttar Pradesh https://t.co/F9ah2UcrWT
#
#
# Comments:
#
# No Comments
#
# Data 80
# 1584053307248898054
# RT @TOICitiesNews: Nitish Kumar should also embark on padyatra, if it’s for publicity: Prashant Kishor https://t.co/11YdyrUBnc
#
#
# Comments:
#
# No Comments
#
# Data 81
# 1584053290492272641
# RT @majorgauravarya: ISRO’s heaviest rocket successfully places 36 OneWeb satellites into orbit. LVM3 makes its entry into the global comme…
#
#
# Comments:
#
# No Comments
#
# Data 82
# 1584053290404548608
# Year after Instagram debut, PM clips draw record views https://t.co/vElrtxDIBM via @timesofindia
# Comments:
#
# No Comments
#
# Data 83
# 1584053289997733888
# RT @toisports: #T20WorldCup: Top 3 concerns for Team India 🇮🇳
#
# READ: https://t.co/ueYO6hKum6 🏏
#
# #T20WorldCup2022 #T20worldcup22 https://t.c…
#
#
# Comments:
#
# No Comments
#
# Data 84
# 1584053287107821569
# @timesofindia The data is crying and saying pollution is due to parali burning. But this anti hindi, anti science government blames diwali, which hasn't even started. Delhi needs change desperately
#
#
# Comments:
#
#
# Data 85
# 1584053270221586432
# RT @TOICitiesNews: Surathkal toll gate to be closed by November end: Dakshina Kannada minister https://t.co/Q3ogfc4Wcc
#
#
# Comments:
#
# No Comments
#
# Data 86
# 1584053268824526848
# 384 infra projects show cost overruns of Rs 4.52 lakh cr https://t.co/gUYvGgIFL8
#
#
# Comments:
#
# No Comments
#
# Data 87
# 1584053267608182784
# Hyderabad: Diverse communities add sparkle to festival of lights https://t.co/JOk5O6z5iM
#
#
# Comments:
#
# No Comments
#
# Data 88
# 1584053264525295616
# RT @HasimaKhatun4: @RajeshRj97766 @Naveen_Odisha @CMO_Odisha @pranabpdas @GovernorOdisha @gapg_dept @otvnews @Kalingatv @odishabhaskar @Sou…
#
#
# Comments:
#
# No Comments
#
# Data 89
# 1584053263380279296
# RT @MukulAgarwal66: @Vyangyokti https://t.co/0627zMYorx
#
#
# Comments:
#
# No Comments
#
# Data 90
# 1584053256426180608
# 'The world needs China', says Xi Jinping after securing third term as leader https://t.co/DAadrC6Sl4
#
#
# Comments:
#
# No Comments
#
# Data 91
# 1584053250894213121
# RT @Jackncyberspace: https://t.co/xt8g33vEpQ
#
# Maybe motivation for decriminalizing Adultery Law
# #NotMyCJI #MaleGenocide #LegalGenocide htt…
#
#
# Comments:
#
# No Comments
#
# Data 92
# 1584053250629963776
# RT @Narende01589313: @dichicorp @mlkhattar @DC_Gurugram @MCManesar @dtcphry @kMakrandIAS @diprogurugram1 @DiprHaryana @cmohry @nishantyadav…
#
#
# Comments:
#
# No Comments
#
# Data 93
# 1584053241805144065
# RT @TOICitiesNews: Amit Shah's Nalanda visit will not yield any positive gain for BJP: Upendra Kushwaha https://t.co/xyqR6eutrP
#
#
# Comments:
#
# No Comments
#
# Data 94
# 1584053232971939840
# RT @dichicorp: @mlkhattar @DC_Gurugram @MCManesar @dtcphry @kMakrandIAS @diprogurugram1 @DiprHaryana @cmohry @DiprHaryana @nishantyadavIAS…
#
#
# Comments:
#
# No Comments
#
# Data 95
# 1584053217951784960
# RT @majorgauravarya: ISRO’s heaviest rocket successfully places 36 OneWeb satellites into orbit. LVM3 makes its entry into the global comme…
#
#
# Comments:
#
# No Comments
#
# Data 96
# 1584053197202546688
# Bengaluru to witness partial solar eclipse for 45 mins on Tuesday | Bengaluru News - Times of India https://t.co/R2MIwhA5H6
#
#
# Comments:
#
# No Comments
#
# Data 97
# 1584053189749637120
# @sagarikaghose @INCIndia @ShashiTharoor @PChidambaram_IN @ghulamnazad @timesofindia @MahuaMoitra Madam you are at point number of article and set to become Women n Child Development Minister. Congratulations @AITCofficial @MamataOfficial @ManavAITC
#
#
# Comments:
#
#
# Data 98
# 1584053186632949766
# #Justice4SSR
# #DRUGS #Drugged
#
# @AmitShah @narendramodi @gautam_adani @myogiadityanath @rashtrapatibhvn @RahulGandhi @priyankagandhi @INCUttarPradesh @INCIndia @AITCofficial @Jduonline @RJDforIndia @AamAadmiParty
# @bollywood_life
# @Bollyhungama @TimesNow @timesofindia @BBCHindi https://t.co/jkV3KQWoju
#
#
# Comments:
#
# No Comments
#
# Data 99
# 1584053165028057088
# @singhesha10 @PMOIndia @ianuragthakur @KirenRijiju @timesofindia @KTRTRS @TelanganaCMO @jayesh_ranjan @suldeep @Media_SAI @DGSAI Amazing and brilliant - Congratulations - Pride of India
#
#
# Comments:
#
#
# Data 100
# 1584053164327591936
# RT @Jackncyberspace: https://t.co/xt8g33vEpQ
#
# Maybe motivation for decriminalizing Adultery Law
# #NotMyCJI #MaleGenocide #LegalGenocide htt…
#
#
# Comments:
#
# No Comments
