# %%
import requests
import wget

# %%
import tweepy

# %%
# Your app's bearer token can be found under the Authentication Tokens section
# of the Keys and Tokens tab of your app, under the
# Twitter Developer Portal Projects & Apps page at
# https://developer.twitter.com/en/portal/projects-and-apps
bearer_token = "AAAAAAAAAAAAAAAAAAAAABvFhgEAAAAAWxWdLEnp6pZJsYMUYAi%2BvFrM5oY%3DrtKXQDsTRS4fXYn44RofMurkHUiMeKlBNVaoAHgJAkVg8DD0GS"

# Your app's API/consumer key and secret can be found under the Consumer Keys
# section of the Keys and Tokens tab of your app, under the
# Twitter Developer Portal Projects & Apps page at
# https://developer.twitter.com/en/portal/projects-and-apps
consumer_key = "r5DowaN8eoM9r1PgQ2ezR6UoN"
consumer_secret = "Z29vyH4fDqlYIRhFyKBgpGvcdTOCdpAhqvau53qsP9KVAlFlbS"

# Your account's (the app owner's account's) access token and secret for your
# app can be found under the Authentication Tokens section of the
# Keys and Tokens tab of your app, under the
# Twitter Developer Portal Projects & Apps page at
# https://developer.twitter.com/en/portal/projects-and-apps
access_token = "1576162990247682049-EsSWVFhd5Z3DrXFZiDkHpN57eRTGXu"
access_token_secret = "qAExjQzAHHkf4FN1LAfZHGocw2E98djMZvmNvEskJQRyr"

# %%
# You can authenticate as your app with just your bearer token
client = tweepy.Client(bearer_token=bearer_token)

# %%
# If the authentication was successful, this should print the
# screen name / username of the account
print(client)
# Out:
# <tweepy.client.Client object at 0x000001B0F75E9EE0>

# %% [markdown]
# ## OPEN A CSV FILE AND WRITE THE RESPONSE TO IT

# %%
import csv

# %%
def getComments(id):
    api="https://api.twitter.com/2/tweets/search/recent?query=conversation_id:" + str(id) + "&tweet.fields=in_reply_to_user_id,author_id,created_at,conversation_id"
    response = requests.get(api,headers={"Authorization":"Bearer AAAAAAAAAAAAAAAAAAAAAEnThwEAAAAAO1yTEzATZBIFaa6R7lw8TH7bK3U%3DXswu28WNIUXOUnucNkz7AA0y4U9qxyzBHxsPEs3eDrC3WLmm9o"})
    #print(response.json())
    return response

# %%
def getImageURL(id):
    api="https://api.twitter.com/2/tweets?ids="+ str(id) +"&expansions=attachments.media_keys&media.fields=duration_ms,height,media_key,preview_image_url,public_metrics,type,url,width,alt_text"
    response = requests.get(api,headers={"Authorization":"Bearer AAAAAAAAAAAAAAAAAAAAAEnThwEAAAAAO1yTEzATZBIFaa6R7lw8TH7bK3U%3DXswu28WNIUXOUnucNkz7AA0y4U9qxyzBHxsPEs3eDrC3WLmm9o"})
    str1 = None
    if 'includes'in response.json():
        if 'url'in response.json()['includes']['media'][0]:
            str1 = str(response.json()['includes']['media'][0]['url'])
        elif 'preview_image_url'in response.json()['includes']['media'][0]:
            str1 = str(response.json()['includes']['media'][0]['preview_image_url'])
    return str1

# %%
def downloadImage(url):
    file_name = wget.download(url)
    return file_name

# %%
def getPosts(response,writer):
    data = response.data
    t=0
    for trump in data:
        t+=1
        print()
        print("Data",t)
        print(trump.id)
        print(trump.text)
        st = trump.text
        index = st.rfind("https")
        
        print('\n')
    
        #api ="https://api.twitter.com/2/tweets/search/recent?query=conversation_id:" + str(trump.id) + "&tweet.fields=in_reply_to_user_id,author_id,created_at,conversation_id"
        res = getConversationId(trump.id)
        #print("Comments!!",t)
        conversation_id = res.json()['data'][0]['conversation_id']
        
        print('Comments:\n')
        res = getComments(conversation_id)
        
        imageURL = getImageURL(trump.id)
        file = ''
        
        if imageURL:
            imageFile = downloadImage(imageURL)
            file = imageFile
            
        
        post_row = ["P:"+str(trump.id), '', file, trump.text, 'Caption', "NA" if (index == -1) else st[index:], '', '', '', '', '', '']
        writer.writerow(post_row)
                 
        
        if 'data' not in res.json():
            print("No Comments")
        else:
            #print(res.json())
            for data in res.json()['data']:
                #print(data['text'])
                cmnt_row = ["P:"+str(trump.id), '', '', data['text'], 'Additional Comment','NA', '', '', '', '', '', '']
                writer.writerow(cmnt_row)

# %%
def getConversationId(id):
    api = "https://api.twitter.com/2/tweets?ids=" + str(id) + "&tweet.fields=author_id,conversation_id,created_at,in_reply_to_user_id,referenced_tweets&expansions=author_id,in_reply_to_user_id,referenced_tweets.id&user.fields=name,username"
    response = requests.get(api,headers={"Authorization":"Bearer AAAAAAAAAAAAAAAAAAAAAEnThwEAAAAAO1yTEzATZBIFaa6R7lw8TH7bK3U%3DXswu28WNIUXOUnucNkz7AA0y4U9qxyzBHxsPEs3eDrC3WLmm9o"})
    #print(response.json())
    return response

# %%
f = open('SrBachchan.csv', 'w', encoding='UTF16',newline='')
writer = csv.writer(f)

#Insert header into csv file
header = ['POST_ID','POST_LINK','IMAGES_ID','Text','Text Type', 'MEDIA_URL', 'Text OCR', 'Language of Text','Hate Speech','Profane','Sentiment','Targeted Insult']
writer.writerow(header)

response = client.search_recent_tweets("SrBachchan", max_results=100)
getPosts(response,writer)
#print(response)
f.close()
# Out:
# Data 1
# 1587297841331904512
# @SrBachchan ओम श्री सूर्य देवाय नमः सूर्य नमस्कार करते हुए आदरणीय मेरे प्यार श्री बच्चन सर को मेरा प्यार भरा नमस्कार🙏🌞🌹🌺🌷🙏 good morning my dear sir
#
#
# Comments:
#
# No Comments
#
# Data 2
# 1587297593607917568
# इसी को "दिव्य धर्म यज्ञ दिवस" के रूप में मनाया जा रहा है।
# 👉अधिक जानकारी के लिए Sant Rampal Ji Maharaj YouTube Channel Visit करें।
# @AmitShah @rajnathsingh @PMOIndia @cmohry @aajtak @ABPNews @ZeeNews @msdhoni @imVkohli @SrBachchan @hindu @HinduAmericans @BBC @Dev_Fadnavis
#
#
# Comments:
#
#
# Data 3
# 1587297454793555968
# RT @TUKESHWARRAJAK9: #दिव्य_धर्म_यज्ञ_दिवस
# परमात्मा कबीर साहिब जी कैसा रूप बनाकर 9 लाख बैलों के ऊपर विशाल भंडारे के लिए समान लात कर लाए थे…
#
#
# Comments:
#
# No Comments
#
# Data 4
# 1587297443154366464
# @RituRaiSharma5 @ANURADHARAHEJA @JasbirKapoorEF @allaukhina2 @manishm1942 @GangulySunetra @StLouisgirl123 @MukherjiRatna @Dipanka82446090 @israilbachchan @Partho701 @SandeepKhurana @KalaYadav3 @HemlataArtist @vikasm12345 @addzz8 @Ashabachchan @shivsoham @MaheshBSolanki4 @SohamBoricha_AB @ManojVaid15 @CqZVBx8jExr0F3b @KTundla @king_ajaz786 @Shailes33357760 @SrBachchan @Inga_Polina @pamelaarora @anuradha_raheja @EfvijayKumar @KarabashevaAmi1 @Ravi_AB_EF @yadavsunanda08 @Jitendr40494554 @Queen80169771 @allaukhinaa @AmiraMaly @Gopalbachchan @Chandra69172171 @nileshbodawala @AmarjeetKumar70 @sureshjumani @ArthVaishnav @bigb21bigbshiv @MosesSapir @ruchi_ABEF @Bigbefamily @LilyPittz @SUMAN_KAUR12 #HappyBirthdayAishwaryaRai ji
# Wishing you a very happy birthday,
# Wish you all the best n family,
# #GodBless ❤️🙏💐💐 https://t.co/RSvdjs99Wv
#
#
# Comments:
#
# 100% [............................................................................] 185958 / 185958
# Data 5
# 1587297383041204224
# @mahendraJC @SrBachchan Satya vachan 🙏He does surprise us all with that one  perfect powerhouse act every decade and so!
#
#
# Comments:
#
#
# Data 6
# 1587297250371596288
# @EfSajidKhan @SrBachchan https://t.co/uXoeRtKOUU
#
#
# Comments:
#
# 100% [..............................................................................] 99395 / 99395
# Data 7
# 1587297164006653954
# Wish you many many happy returns of the day dear Aishwarya Rai Bachchan
# @AishwaryaRaiWeb @SrBachchan @juniorbachchan
#
#
# Comments:
#
# No Comments
#
# Data 8
# 1587297146595786752
# @PravsAhuja19 @SrBachchan Good Morning🙏❤🌹 https://t.co/hkjdfvDDpD
#
#
# Comments:
#
# 100% [..............................................................................] 37059 / 37059
# Data 9
# 1587297043105533952
# RT @arkomajumdaref: @PrashantLoveAB @SrBachchan Bachchan Morning 🖤🖤🖤 https://t.co/2UAaXKoTMl
#
#
# Comments:
#
# 100% [..............................................................................] 29169 / 29169No Comments
#
# Data 10
# 1587296915925843968
# RT @bhavjitsingh_: 1st Nov, 1984
# When genocide &amp; planned terror was unleashed against innocent Sikhs of Delhi by heirs of Indira Gandhi
#
# Li…
#
#
# Comments:
#
# No Comments
#
# Data 11
# 1587296738322182144
# लाखों लोगों को अपनी शरण में लिया।
# 👉अधिक जानकारी के लिए Sant Rampal Ji Maharaj YouTube Channel Visit करें।
# @AmitShah @rajnathsingh @PMOIndia @cmohry @aajtak @ABPNews @ZeeNews @msdhoni @imVkohli @SrBachchan @hindu @HinduAmericans @BBC @Dev_Fadnavis @chouhanshivraj @manoharlalbjp
#
#
# Comments:
#
#
# Data 12
# 1587296518943694849
# RT @girishjohar: A long wknd release for #ProjectK onApril 10, 2024
# 💥🎉💣💞💥🎉💣💫🔥❤️‍🔥
# @SrBachchan
# #Prabhas
# @nagashwin7  @deepikapadukone @Ash…
#
#
# Comments:
#
# No Comments
#
# Data 13
# 1587296409551708161
# RT @satyanarayand: @Kulpreetyadav @DisneyPlusHS @KicchaSudeep @KicchaSudeep is the best..what a voice like @SrBachchan
#
#
# Comments:
#
# No Comments
#
# Data 14
# 1587295970366083072
# RT @LordKabirSahib: #दिव्य_धर्म_यज्ञ_दिवस
# काशी में परमेश्वर कबीर बंदीछोड़ जी के विरोधी साधुओं-काजी-मुल्लाओं ने षड़यंत्र रचकर तीन दिवसीय भोज…
#
#
# Comments:
#
# No Comments
#
# Data 15
# 1587295958278160384
# #दिव्य_धर्म_यज्ञ_दिवस
# काशी में परमेश्वर कबीर बंदीछोड़ जी के विरोधी साधुओं-काजी-मुल्लाओं ने षड़यंत्र रचकर तीन दिवसीय भोजन-भंडारे(लंगर) के झूठे पत्र परमेश्वर की ओर से डाले थे। जिस कारण से 18 लाख भक्त तथा संत व अन्य व्यक्ति लंगर खाने आ गए थे।
# 7_8_9 November
# @SrBachchan https://t.co/GdbIHaAEs2
#
#
# Comments:
#
# 100% [............................................................................] 237740 / 237740No Comments
#
# Data 16
# 1587295947716890624
# लाखों लोगों को अपनी शरण में लिया।
# 👉अधिक जानकारी के लिए Sant Rampal Ji Maharaj YouTube Channel Visit करें।
# @AmitShah @rajnathsingh @PMOIndia @cmohry @aajtak @ABPNews @ZeeNews @msdhoni @imVkohli @SrBachchan @hindu @HinduAmericans @BBC @Dev_Fadnavis @chouhanshivraj @manoharlalbjp
#
#
# Comments:
#
#
# Data 17
# 1587295925579358210
# RT @satyanarayand: @Kulpreetyadav @DisneyPlusHS @KicchaSudeep @KicchaSudeep is the best..what a voice like @SrBachchan
#
#
# Comments:
#
# No Comments
#
# Data 18
# 1587295805408301056
# RT @Wings35539354: आ जाती. @SrBachchan का परिवार ये अफोर्ड कर सकता है कि उनकी नातिन बिना शादी के माँ बन जाये, पार्टी में भीड़ भी इक्कठा हो…
#
#
# Comments:
#
# No Comments
#
# Data 19
# 1587295737066721281
# जिंदगी मे और कुछ पाना है l https://t.co/cbzomLblZ1
#
#
# Comments:
#
# No Comments
#
# Data 20
# 1587295681944817665
# @RanjitOne @vivekagnihotri @AnupamPKher @SrBachchan @anandmahindra @akshaykumar @ajaydevgn @TVMohandasPai @NSaina @sachin_rt Vivek already has done that on his timeline by blaming AAP for this mishap calling it conspiracy!! He is a predictable cheap ****
#
#
# Comments:
#
#
# Data 21
# 1587295615691608064
# कमजोर कोई नहीं होता, सब वक़्त का खेल है......
# #G4UEntertainment @SrBachchan ji https://t.co/8yNAmJxyYP
#
#
# Comments:
#
# 100% [............................................................................] 105517 / 105517No Comments
#
# Data 22
# 1587295576659750913
# RT @SonyTV: KBC ke manch ka aaj badlega aandaaz, jab @SrBachchan ji #PoojaTripathy ji ki karenge taareef aur karenge unke saath lion walk!…
#
#
# Comments:
#
# No Comments
#
# Data 23
# 1587295555897921536
# RT @LilyPittz: @SrBachchan Happy 80th birthday sire 🪔 344 days to 🎂  Respects! @juniorbachchan #AB80 #AmitabhBachchan https://t.co/mdmNdO9B…
#
#
# Comments:
#
# No Comments
#
# Data 24
# 1587295446816346112
# RT @imovie_enthu: One of the best films of 2022 - #Runway34. Hats off to @ajaydevgn's vision. Flight scenes are on par with international s…
#
#
# Comments:
#
# No Comments
#
# Data 25
# 1587295408169967616
# Sir forget common men
# Where r these coward nationalist
#
# @SirPareshRawal
# @AnupamPKher
# @akshaykumar
# @actormanojjoshi
# @SrBachchan
# @dreamgirlhema
#
# Pin drop silence, So what if people dies but don't question d ruler
#
# Congress se nafrat ne in sab ko insaan k layak bhi nhi chhoda https://t.co/DchpqPULUT
#
#
# Comments:
#
# No Comments
#
# Data 26
# 1587295241123794949
# @ASHISH9696875 @myogiadityanath @SatishSharmaBBK @mp_kaushal @SrBachchan @aksharmaBharat @RamBhar99463505 @aajtak @AU_LucknowNews @Jyoti67761638 @dheerusinghh https://t.co/xK1vKDZ1Ue
#
#
# Comments:
#
# 100% [............................................................................] 115050 / 115050
# Data 27
# 1587295100714962944
# RT @PravsAhuja19: GM @SrBachchan Boss
# Thought for 2day
# “Accept life like a pair of walking legs. The foot forward has no pride and the foo…
#
#
# Comments:
#
# No Comments
#
# Data 28
# 1587294797835943938
# @SrBachchan
# Has someone locked your tongue Mr.Bachchan or don’t have spine to talk about this…..
# https://t.co/B0PPm7rukn
#
#
# Comments:
#
# No Comments
#
# Data 29
# 1587294475000291328
# @PrashantLoveAB @SrBachchan Bachchan Morning Gurudev ji &amp; to you Dear Prashant Bhaiya ❤🆎️🌹 https://t.co/DoUF8EAQxq
#
#
# Comments:
#
# 100% [..............................................................................] 46905 / 46905
# Data 30
# 1587294367911481344
# RT @rajinikanth: The legend.. someone who has inspired me always… the one true sensation and superhero of our glorious Indian film fraterni…
#
#
# Comments:
#
# No Comments
#
# Data 31
# 1587294308482228224
# Do you remember when you joined Twitter? I do! #MyTwitterAnniversary @SrBachchan https://t.co/VqP0hcOGYh
#
#
# Comments:
#
# 100% [............................................................................] 112561 / 112561No Comments
#
# Data 32
# 1587294203700449280
# RT @LilyPittz: @SrBachchan @SrBachchan 344 days to 🎂 🪔 Respects! @juniorbachchan https://t.co/NxcdtXVIGW
#
#
# Comments:
#
# 100% [..............................................................................] 92651 / 92651No Comments
#
# Data 33
# 1587294196943114240
# GM @SrBachchan Boss
# Thought for 2day
# “Accept life like a pair of walking legs. The foot forward has no pride and the foot behind has no shame. Both know their situation will soon change”
# Have a lovely day 💐💕🌹💕
# Regards ~ प्रवीण आहूजा (नॉएडा) https://t.co/rsYvThCxhC
# Comments:
#
# 100% [..............................................................................] 28418 / 28418
# Data 34
# 1587294182112366592
# RT @girishjohar: A long wknd release for #ProjectK onApril 10, 2024
# 💥🎉💣💞💥🎉💣💫🔥❤️‍🔥
# @SrBachchan
# #Prabhas
# @nagashwin7  @deepikapadukone @Ash…
#
#
# Comments:
#
# No Comments
#
# Data 35
# 1587294154622611456
# RT @Wings35539354: आ जाती. @SrBachchan का परिवार ये अफोर्ड कर सकता है कि उनकी नातिन बिना शादी के माँ बन जाये, पार्टी में भीड़ भी इक्कठा हो…
#
#
# Comments:
#
# No Comments
#
# Data 36
# 1587294041443831808
# @SrBachchan मोरबी में जान गवाने वालो पर दो शब्द भी नही है आपके पास, या कोई ट्वीट स्पॉन्सर नही मिला, हद है
#
#
# Comments:
#
#
# Data 37
# 1587293943644901377
# RT @manav_mandir: @manav_mandir @KANABARDr @sandeshnews @NHMGujarat @Jasminbhuva2 @BJP4Amreli @PRupala @sanghani99 @narendramodi
# @AmitShah…
#
#
# Comments:
#
# No Comments
#
# Data 38
# 1587293845212909569
# RT @PrashantLoveAB: Bachchan Morning to #Paa of Indian Cinema and all friends.
#
# चरण स्पर्श गुरुदेव @SrBachchan Sir https://t.co/XYTMgkNzZ3
#
#
# Comments:
#
# 100% [..............................................................................] 44175 / 44175No Comments
#
# Data 39
# 1587293442476212224
# @SrBachchan 😊😊
#
#
# Comments:
#
#
# Data 40
# 1587293350914293760
# @SrBachchan You should be shamed at your self.. https://t.co/LztG0SnEXE
#
#
# Comments:
#
# No Comments
#
# Data 41
# 1587293248896188417
# RT @jitendrakundar1: सीएम साहब श्री @ashokgehlot51 जी,मान्यवर ये पत्र देने आया था,फिर भी आपको पहुंचा रहा हूं,उम्मीद है। @RajCMO @PMOIndia @…
#
#
# Comments:
#
# No Comments
#
# Data 42
# 1587292690474901505
# RT @manishm1942: @PravsAhuja19 @SrBachchan Khoob Bahut Khoob 👏👏👌👌👌👌👌👍👍✌️
#
#
# Comments:
#
# No Comments
#
# Data 43
# 1587292606123212801
# RT @girishjohar: A long wknd release for #ProjectK onApril 10, 2024
# 💥🎉💣💞💥🎉💣💫🔥❤️‍🔥
# @SrBachchan
# #Prabhas
# @nagashwin7  @deepikapadukone @Ash…
#
#
# Comments:
#
# No Comments
#
# Data 44
# 1587292173061365762
# RT @Meenu_NewYork: @SrBachchan महानालायक जी .. बहूदगी के सायं पूरी दुनिया को ज्ञान देते हैं, संस्कार और संस्कृति पर भाषण देते हैं मगर खुद…
#
#
# Comments:
#
# No Comments
#
# Data 45
# 1587291935366033411
# @bikajifoodsbkn
# @ashokgehlot51
# @SrBachchan
# क्या फायदा साहब शुद्ध के लिए युद्ध अभियान का
# 22 अक्टूबर को 1 kg राजभोग रसगुल्ले का प्रोडक्ट लिया 24अक्टूबर को दिवाली वाले दिन ओपन किया इस तरह के रसगुल्ले निकले 24,25,26,को181 पर बात नही हुई 27 को शियाकत की अभी तक उचित कार्यवाही नहीं https://t.co/zgHqaftmqh
#
#
# Comments:
#
# 100% [..............................................................................] 51119 / 51119No Comments
#
# Data 46
# 1587291699801300993
# RT @satyanarayand: @Kulpreetyadav @DisneyPlusHS @KicchaSudeep @KicchaSudeep is the best..what a voice like @SrBachchan
#
#
# Comments:
#
# No Comments
#
# Data 47
# 1587291527729926144
# @PrashantLoveAB @SrBachchan Bachchan Morning 🖤🖤🖤 https://t.co/2UAaXKoTMl
#
#
# Comments:
#
# 100% [..............................................................................] 29169 / 29169
# Data 48
# 1587291412365643778
# RT @SonyTV: KBC ke manch ka aaj badlega aandaaz, jab @SrBachchan ji #PoojaTripathy ji ki karenge taareef aur karenge unke saath lion walk!…
#
#
# Comments:
#
# No Comments
#
# Data 49
# 1587291290118430720
# RT @PrashantLoveAB: Bachchan Morning to #Paa of Indian Cinema and all friends.
#
# चरण स्पर्श गुरुदेव @SrBachchan Sir https://t.co/XYTMgkNzZ3
#
#
# Comments:
#
# 100% [..............................................................................] 44175 / 44175No Comments
#
# Data 50
# 1587290943220109314
# RT @PravsAhuja19: “काश ख़ुशियों की कहीं दुकान होती,
# और हमारी वहाँ पहचान होती,
# आपका हर पल ख़ुशियों से भर देता,
# क़ीमत उसकी चाहे हमारी जान हो…
#
#
# Comments:
#
# No Comments
#
# Data 51
# 1587290918637355009
# Happy birthday 🎂 #AishwaryaRaiBachchan Ji
# @juniorbachchan ,
# @SrBachchan , https://t.co/k8IRDKzcT5
#
#
# Comments:
#
# 100% [..............................................................................] 61717 / 61717No Comments
#
# Data 52
# 1587290874735603712
# RT @SrBachchan: T 4455 - ज़बान को शब्दों की ज़रूरत नहीं होती  ! कई बार वे खुद ही बोल देती हैं  !! 🤣🤣🤣 https://t.co/vsafMwfMiX
#
#
# Comments:
#
# 100% [............................................................................] 182586 / 182586No Comments
#
# Data 53
# 1587290320365973504
# ఎప్పటికి తరగని అందానికి పుట్టినరోజు శుభాకాంక్షలు
# 💖😘💖 #ఐష్ 😘🥰😘
# #HBD SeXy #AishwaryaRaiBachchan 💐🎂
# ✨
# #aishwaryarai
# @SrBachchan https://t.co/qnotvplbka
#
#
# Comments:
#
# 100% [............................................................................] 123947 / 123947No Comments
#
# Data 54
# 1587290298882789376
# RT @mahendraJC: Am I the only one who feels @SrBachchan is gonna go into an over drive phase of his career and make perhaps his best films…
#
#
# Comments:
#
# No Comments
#
# Data 55
# 1587290038429429762
# विचित्र किन्तु सत्य
#
# @SrBachchan https://t.co/3gVhmEaGVj
#
#
# Comments:
#
# 100% [..............................................................................] 80891 / 80891No Comments
#
# Data 56
# 1587289893079769088
# @MinaxhiSeshadri @MinaxhiSeshadri @mithunda_off  @SrBachchan
# #AmitabhBachchan  #mithun #meenakshiseshadri https://t.co/5GClfuVpWj
#
#
# Comments:
#
# 100% [............................................................................] 101318 / 101318
# Data 57
# 1587289805716455424
# RT @MukherjiRatna: Once for all of us from none other than @SrBachchan ji.🙏🏼🙏🏼 Really we are blessed always.🙏🏼🙏🏼 Thank you so much sir. htt…
#
#
# Comments:
#
# No Comments
#
# Data 58
# 1587289620697747456
# @MrsGandhi Old man Modi is an versatile actor, in front of @narendramodi , Bollywood stars like @SrBachchan have to Beg in acting. Modi great in dramatic scenes
#
#
# Comments:
#
#
# Data 59
# 1587289514992889856
# RT @Santosh77071754: #HappyHalloween #mondaythoughts #instagramdown
# तत्वदर्शी पूर्ण @SaintRampalJiM के सानिध्य में  #दिव्य_धर्म_यज्ञ_दिवस…
#
#
# Comments:
#
# No Comments
#
# Data 60
# 1587289468750422019
# @AmitShah Om Shri Durga Bhavanihey Namaha
# SAI SHARANAM AMIT SHAH SIR JI🙏
# AUR
# AMMA ko BHI SAI SHARANAM
# SHUBODHAYAM SIR JI
# AAPKO BHI
# SHUBHAKANKSHALU AMIT SHAH SIR
# @SrilalithaSings
# @RojaSelvamaniRK
# 🙏🪴@realyssharmila @ysjagan🪴🙏
# @rashtrapatibhvn
# @narendramodi
# @AnupamPKher
# @SrBachchan https://t.co/IcPxeZKi7K
#
#
# Comments:
#
# 100% [..............................................................................] 50512 / 50512
# Data 61
# 1587289177565327361
# RT @bhavjitsingh_: 1st Nov, 1984
# When genocide &amp; planned terror was unleashed against innocent Sikhs of Delhi by heirs of Indira Gandhi
#
# Li…
#
#
# Comments:
#
# No Comments
#
# Data 62
# 1587289127690522624
# RT @MukherjiRatna: Happy birthday #AishwaryaRaiBachchan ji.
# @SrBachchan Good morning my most adorable n respected Amit ji. 🙏🙏 Plz convey m…
#
#
# Comments:
#
# No Comments
#
# Data 63
# 1587289048254935040
# RT @DeepakDaas19: इसी को "दिव्य धर्म यज्ञ दिवस" के रूप में मनाया जा रहा है।
# #दिव्य_धर्म_यज्ञ_दिवस*
#
# *7_8_9 November*
# @akshaykumar
# @SrBachc…
#
#
# Comments:
#
# No Comments
#
# Data 64
# 1587288880755216386
# RT @DeepaParent: Interesting fact. Khuda Gawah was shot in Mazar-e-Sharif and Kabul just after the Soviets left and Najibullah Ahmadzai was…
#
#
# Comments:
#
# No Comments
#
# Data 65
# 1587288634566537216
# RT @LalaThedaktar: Agree With @SrBachchan 's Latest Insta Post !!
#
# #DeepikaPadukone https://t.co/iq0fHOuUis
#
#
# Comments:
#
# 100% [..............................................................................] 44431 / 44431No Comments
#
# Data 66
# 1587288533265715200
# RT @Santosh77071754: #दिव्य_धर्म_यज्ञ_दिवस
# दिव्य धर्म यज्ञ दिवस पर विशेष
# सन 1513 में 18 लाख लोगों को काशी में कबीर परमात्मा ने तीन दिन तक…
#
#
# Comments:
#
# No Comments
#
# Data 67
# 1587288268781096960
# @KSChithra 🙏🪴SAI SHARANAM AMMA 🪴🙏
#     🙏💐PRANAM AMMA💐🙏
# 🙏💐SHUBODHAYAM AMMA💐🪴
# 🙏SHUBHAKANKSHALU AMMA🪴🙏
# @SrilalithaSings @sooryagayathari 🙏
# @MsAnushkaShetty @KeerthyOfficial
# @IamKrithiShetty
# @rashtrapatibhvn @DrTamilisaiGuv
# @narendramodi @RahulVellal
# @AnupamPKher
# @SrBachchan https://t.co/xScDl2AKVX
#
#
# Comments:
#
# 100% [..............................................................................] 54559 / 54559
# Data 68
# 1587288267309080577
# RT @RangareRajesh: Happy Birthday To the Most Beautiful Actress. ❤️
# #bestwishes
# #AishwaryaRaiBachchan
# @juniorbachchan
# @SrBachchan https://…
#
#
# Comments:
#
# No Comments
#
# Data 69
# 1587288229253767168
# RT @RangareRajesh: Happy Birthday To the Most Beautiful Actress. ❤️
# #bestwishes
# #AishwaryaRaiBachchan
# @juniorbachchan
# @SrBachchan https://…
# Comments:
#
# No Comments
#
# Data 70
# 1587288068541022209
# RT @satyanarayand: @Kulpreetyadav @DisneyPlusHS @KicchaSudeep @KicchaSudeep is the best..what a voice like @SrBachchan
#
#
# Comments:
#
# No Comments
#
# Data 71
# 1587288053646692354
# RT @RangareRajesh: Happy Birthday To the Most Beautiful Actress. ❤️
# #bestwishes
# #AishwaryaRaiBachchan
# @juniorbachchan
# @SrBachchan https://…
#
#
# Comments:
#
# No Comments
#
# Data 72
# 1587287844519047168
# Wish you a very happy birthday to Aishwarya Rai Bachchan mam and his family let's celebrate and enjoy this time. 🎉🎉🎁🎁👏👏👏 @SrBachchan @juniorbachchan #HappyBirthdayAishwaryaRai  #HAPPYBIRTHDAY https://t.co/oUcwXzy31l
#
#
# Comments:
#
# 100% [............................................................................] 103581 / 103581No Comments
#
# Data 73
# 1587287840387366912
# RT @bhavjitsingh_: 1st Nov, 1984
# When genocide &amp; planned terror was unleashed against innocent Sikhs of Delhi by heirs of Indira Gandhi
#
# Li…
#
#
# Comments:
#
# No Comments
#
# Data 74
# 1587287794912677888
# @iamsrk @SrBachchan #wewantraoneback
#
#
# Comments:
#
#
# Data 75
# 1587287776005066753
# RT @satyanarayand: @Kulpreetyadav @DisneyPlusHS @KicchaSudeep @KicchaSudeep is the best..what a voice like @SrBachchan
#
#
# Comments:
#
# No Comments
#
# Data 76
# 1587287680953774086
# Happy Birthday To the Most Beautiful Actress. ❤️
# #bestwishes
# #AishwaryaRaiBachchan
# @juniorbachchan
# @SrBachchan https://t.co/P5y7eceKsF
#
#
# Comments:
#
# 100% [............................................................................] 219634 / 219634No Comments
#
# Data 77
# 1587287618211164160
# RT @girishjohar: A long wknd release for #ProjectK onApril 10, 2024
# 💥🎉💣💞💥🎉💣💫🔥❤️‍🔥
# @SrBachchan
# #Prabhas
# @nagashwin7  @deepikapadukone @Ash…
#
#
# Comments:
#
# No Comments
#
# Data 78
# 1587287561055088641
# RT @sanjay_patodiya: @SrBachchan कड़वी बात भी हँसकर कही जाए तो मीठी हो जाती है..।
#
#
# Comments:
#
# No Comments
#
# Data 79
# 1587287519229399040
# RT @MohanDa29949070: #KnowAboutChhathPuja
# छठी मैया और सूर्यदेव की पूजा से हमारे दुःख दूर नहीं हो सकते। बल्कि परमेश्वर कविर्देव (कबीर साहेब)…
#
#
# Comments:
#
# No Comments
#
# Data 80
# 1587287515580751872
# @JasbirKapoorEF @RituRaiSharma5 @allaukhina2 @manishm1942 @GangulySunetra @StLouisgirl123 @MukherjiRatna @Dipanka82446090 @ANURADHARAHEJA @israilbachchan @Partho701 @SandeepKhurana @KalaYadav3 @HemlataArtist @vikasm12345 @addzz8 @Ashabachchan @shivsoham @MaheshBSolanki4 @SohamBoricha_AB @ManojVaid15 @CqZVBx8jExr0F3b @KTundla @king_ajaz786 @Shailes33357760 @SrBachchan @Inga_Polina @pamelaarora @anuradha_raheja @EfvijayKumar @KarabashevaAmi1 @Ravi_AB_EF @yadavsunanda08 @Jitendr40494554 @Queen80169771 @allaukhinaa @AmiraMaly @Gopalbachchan @Chandra69172171 @nileshbodawala @AmarjeetKumar70 @sureshjumani @ArthVaishnav @bigb21bigbshiv @MosesSapir @ruchi_ABEF @Bigbefamily @LilyPittz @SUMAN_KAUR12 #UniqueConcept #WallmountPhoto #GlowPhotoNFrame without drill on the wall,select da #DesignNPhoto as your like what u want 2 display on the wall🙂
#
# 🇺 🇻  ⁿ 🇦 🇨  ｌｉｇｈｔｍｏｄｅ ｓｙｓｔｅｍ
#
# 🇬 🇱 🇴 🇼  ⁱⁿ ᵗʰᵉ ᵈᵃʳᵏ
#
# #卄ａｐｐｙ卄ｅｌｌｏｗｗｅｅｎ
#
# ☀️#Eｏｎｅ❤️🙏🥳 https://t.co/rBWbgkRXHM
#
#
# Comments:
#
# 100% [............................................................................] 158467 / 158467
# Data 81
# 1587287425784500225
# RT @girishjohar: A long wknd release for #ProjectK onApril 10, 2024
# 💥🎉💣💞💥🎉💣💫🔥❤️‍🔥
# @SrBachchan
# #Prabhas
# @nagashwin7  @deepikapadukone @Ash…
#
#
# Comments:
#
# No Comments
#
# Data 82
# 1587287399088132097
# RT @DeepakDaas19: इसी को "दिव्य धर्म यज्ञ दिवस" के रूप में मनाया जा रहा है।
# #दिव्य_धर्म_यज्ञ_दिवस*
#
# *7_8_9 November*
# @akshaykumar
# @SrBachc…
#
#
# Comments:
#
# No Comments
#
# Data 83
# 1587287327332012032
# RT @Vivek19111981: #AishwaryaRaiBachchan
#
# Happy Birthday
#
# @SrBachchan, Please convey our messages
#
#
# Comments:
#
# No Comments
#
# Data 84
# 1587287220997980161
# @SrBachchan की लुगाई, @juniorbachchan की माई, #JayaBachchan , फिल्मों में में ही संस्कारी दिखाई देती है 😃 इसका असली रूप असली चरित्र, असली सभ्यता, दो पैरों के बीच तक ही सीमित है। मनुष्य कई बंधनों से बंधा हुआ है,
# यह सिर्फ दो पैरों से बंधी हुई है
#
#
# Comments:
#
# No Comments
#
# Data 85
# 1587287122247311360
# #AishwaryaRaiBachchan
#
# Happy Birthday
#
# @SrBachchan, Please convey our messages
#
#
# Comments:
#
# No Comments
#
# Data 86
# 1587287041506955269
# RT @SrBachchan: T 4435 - तैयार होजाइये हमारी #Goodbye family की तरह गुनगुनाने के लिए यह नया गाना #HappyBirthday ❤️ Stay tuned, song out tom…
#
#
# Comments:
#
# No Comments
#
# Data 87
# 1587287021219119105
# @anandmahindra @SrBachchan @sachin_rt @akshaykumar @iam_juhi anyone? https://t.co/DZVNMYp3Rx
#
#
# Comments:
#
# No Comments
#
# Data 88
# 1587286947147354113
# RT @DeepakDaas19: इसी को "दिव्य धर्म यज्ञ दिवस" के रूप में मनाया जा रहा है।
# #दिव्य_धर्म_यज्ञ_दिवस*
#
# *7_8_9 November*
# @akshaykumar
# @SrBachc…
#
#
# Comments:
#
# No Comments
#
# Data 89
# 1587286939715125248
# RT @satyanarayand: @Kulpreetyadav @DisneyPlusHS @KicchaSudeep @KicchaSudeep is the best..what a voice like @SrBachchan
#
#
# Comments:
#
# No Comments
#
# Data 90
# 1587286906898743296
# इसी को "दिव्य धर्म यज्ञ दिवस" के रूप में मनाया जा रहा है।
# #दिव्य_धर्म_यज्ञ_दिवस*
#
# *7_8_9 November*
# @akshaykumar
# @SrBachchan https://t.co/bK9UZY4VXv
#
#
# Comments:
#
# 100% [..............................................................................] 61861 / 61861
# Data 91
# 1587286878570831872
# RT @girishjohar: A long wknd release for #ProjectK onApril 10, 2024
# 💥🎉💣💞💥🎉💣💫🔥❤️‍🔥
# @SrBachchan
# #Prabhas
# @nagashwin7  @deepikapadukone @Ash…
#
#
# Comments:
#
# No Comments
#
# Data 92
# 1587286779886899202
# @EfvijayKumar @SrBachchan जय श्री राम 🙏🙏🌸🌸🚩🚩
# जय श्री हनुमान 🙏🙏🌸🌸🚩🚩
#
#
# Comments:
#
#
# Data 93
# 1587286737931624448
# @narendramodi @SrBachchan Happy 80th birthday to Amit Ji. Endless source of energy &amp; enthusiasm...
#
#
# Comments:
#
#
# Data 94
# 1587286648056086529
# RT @girishjohar: A long wknd release for #ProjectK onApril 10, 2024
# 💥🎉💣💞💥🎉💣💫🔥❤️‍🔥
# @SrBachchan
# #Prabhas
# @nagashwin7  @deepikapadukone @Ash…
#
#
# Comments:
#
# No Comments
#
# Data 95
# 1587286578019594240
# RT @PradnyaPawar121: @SrBachchan सर इसी "जुबान" से पेट्रोल की बढती किंमत पर दुःख प्रकट करने वाला ट्वीट कर देते तो अच्छा लगता।🙏🙏 https://t.c…
#
#
# Comments:
#
# No Comments
#
# Data 96
# 1587286516144881665
# RT @RupamNa2966993: @UnaNYKHP @nykkeylong @Nyksindia @MLJ_GoI @AmritMahotsav @sdnykshp @ndtvindia @narendramodi @YASMinistry @Anurag_Office…
#
#
# Comments:
#
# No Comments
#
# Data 97
# 1587286386654482432
# RT @narendramodi: A very happy 80th birthday to Amitabh Bachchan Ji. He is one of India’s most remarkable film personalities who has enthra…
#
#
# Comments:
#
# No Comments
#
# Data 98
# 1587286278084534272
# @KulkarniK9668 Wait for @vivekagnihotri to make "The Bridge Files" starring @AnupamPKher , blaming the Muslims &amp; the Congress Party for the mishap.
# From others pin drop silence @SrBachchan @anandmahindra @akshaykumar @ajaydevgn @TVMohandasPai @NSaina @sachin_rt etc.
#
#
# Comments:
#
#
# Data 99
# 1587286231582670848
# RT @satyanarayand: @Kulpreetyadav @DisneyPlusHS @KicchaSudeep @KicchaSudeep is the best..what a voice like @SrBachchan
#
#
# Comments:
#
# No Comments
#
# Data 100
# 1587286155862880257
# RT @_MohitGahlot_: 1st Nov, 1984
#
# “Will not forget &amp; won’t let you forget”
#
# When genocide &amp; planned terror was unleashed against innocent S…
#
#
# Comments:
#
# No Comments
