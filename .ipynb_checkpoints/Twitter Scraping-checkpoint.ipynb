# %%
import requests
from bs4 import BeautifulSoup

# %%
import tweepy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20560/3485472014.py in <module>
# ----> 1 import tweepy
#
# ModuleNotFoundError: No module named 'tweepy'

# %%
# You can authenticate as your app with just your bearer token
client = tweepy.Client(bearer_token=bearer_token)

# %%
# If the authentication was successful, this should print the
# screen name / username of the account
print(client)

# %%
response = client.search_recent_tweets("Tweepy", max_results=10)

# %%
tweets = response.data

# %%
print(response)
# Out:
# Response(data=[<Tweet id=1577856489372409858 text='2022-10-06 03:01:16.813652 tweepy'>, <Tweet id=1577855986097950723 text='2022-10-06 02:59:16.813627 tweepy'>, <Tweet id=1577855482731036672 text='2022-10-06 02:57:16.813523 tweepy'>, <Tweet id=1577854979460808704 text='2022-10-06 02:55:16.813433 tweepy'>, <Tweet id=1577854476098183168 text='2022-10-06 02:53:16.813679 tweepy'>, <Tweet id=1577854222518755328 text='Tweepy完全に理解した'>, <Tweet id=1577853972790099968 text='2022-10-06 02:51:16.813587 tweepy'>, <Tweet id=1577853469477814275 text='2022-10-06 02:49:16.813664 tweepy'>, <Tweet id=1577852966152929280 text='2022-10-06 02:47:16.813650 tweepy'>, <Tweet id=1577852462836449280 text='2022-10-06 02:45:16.813430 tweepy'>], includes={}, errors=[], meta={'newest_id': '1577856489372409858', 'oldest_id': '1577852462836449280', 'result_count': 10, 'next_token': 'b26v89c19zqg8o3fpzbmmetv5nq57hkx9atml3jxhlnr1'})

# %%
# Each Tweet object has default ID and text fields
for tweet in tweets:
    print(tweet.id)
    print(tweet.text)
# Out:
# 1577856489372409858
# 2022-10-06 03:01:16.813652 tweepy
# 1577855986097950723
# 2022-10-06 02:59:16.813627 tweepy
# 1577855482731036672
# 2022-10-06 02:57:16.813523 tweepy
# 1577854979460808704
# 2022-10-06 02:55:16.813433 tweepy
# 1577854476098183168
# 2022-10-06 02:53:16.813679 tweepy
# 1577854222518755328
# Tweepy完全に理解した
# 1577853972790099968
# 2022-10-06 02:51:16.813587 tweepy
# 1577853469477814275
# 2022-10-06 02:49:16.813664 tweepy
# 1577852966152929280
# 2022-10-06 02:47:16.813650 tweepy
# 1577852462836449280
# 2022-10-06 02:45:16.813430 tweepy

# %%
response = client.search_recent_tweets("realdonaldtrump", max_results=100)

# %%
print(response)
# Out:
# Response(data=[<Tweet id=1577858107052638210 text='https://t.co/Kgmx1u37Uk'>, <Tweet id=1577858024705859585 text='@WhiteHouse45 @POTUS45 @realDonaldTrump @FLOTUS #StopHazarzaGenocide'>, <Tweet id=1577857991256186880 text='@middleageriot Explains the shade of spray tan @realdonaldtrump uses'>, <Tweet id=1577857927783800833 text="RT @realJoelFischer: Hey you, yes you, see that guy running to show respect to our man and woman in blue, That's my President, and Yours.…">, <Tweet id=1577857810645192705 text='RT @GOPJake: Fauci just said on Fox News that he is pleased with how @realDonaldTrump delivered the truth about the Coronavirus to the publ…'>, <Tweet id=1577857577509015552 text='A clothes pin would make a better president than @realDonaldTrump'>, <Tweet id=1577857390711562240 text='RT @SGTValadez: I was just checking.\n\n@realDonaldTrump\n\nMaybe soon….🤔'>, <Tweet id=1577857377797345280 text='@ThePandemica @elonmusk @Twitter @realDonaldTrump The only thing that will happen is that pe
# ...

# %%
trumps = response.data

# %%
for trump in trumps:
    print(trump.id)
    print(trump.text)
    st = trump.text
    print(type(st))
    index = st.rfind("https")
    print(index)
    print(st[index:])
    print('\n')
# Out:
# 1577858107052638210
# https://t.co/Kgmx1u37Uk
# <class 'str'>
# 0
# https://t.co/Kgmx1u37Uk
#
#
# 1577858024705859585
# @WhiteHouse45 @POTUS45 @realDonaldTrump @FLOTUS #StopHazarzaGenocide
# <class 'str'>
# -1
# e
#
#
# 1577857991256186880
# @middleageriot Explains the shade of spray tan @realdonaldtrump uses
# <class 'str'>
# -1
# s
#
#
# 1577857927783800833
# RT @realJoelFischer: Hey you, yes you, see that guy running to show respect to our man and woman in blue, That's my President, and Yours.…
# <class 'str'>
# -1
# …
#
#
# 1577857810645192705
# RT @GOPJake: Fauci just said on Fox News that he is pleased with how @realDonaldTrump delivered the truth about the Coronavirus to the publ…
# <class 'str'>
# -1
# …
#
#
# 1577857577509015552
# A clothes pin would make a better president than @realDonaldTrump
# <class 'str'>
# -1
# p
#
#
# 1577857390711562240
# RT @SGTValadez: I was just checking.
#
# @realDonaldTrump
#
# Maybe soon….🤔
# <class 'str'>
# -1
# 🤔
#
#
# 1577857377797345280
# ...

# %% [markdown]
# ## OPEN A CSV FILE AND WRITE THE RESPONSE TO IT

# %%
import csv

# %%
header = ['PID', 'Text', 'Media', 'MediaURL', 'Emotion', 'HateSpeech']

# %%
for trump in trumps:
    st = trump.text
    index = st.rfind("https")
    print("NA" if (index == -1) else st[index:])
# Out:
# https://t.co/Kgmx1u37Uk
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# https://t.co/PXSNHm7vNX
# NA
# https://t.co/d2ednGHtbJ
# NA
# https://t.co/cCtsKCdsAr
# NA
# NA
# https://t.co/J2oKDP9tVB
# https://t.co/mIF9gLnYpp
# NA
# NA
# https://t.co/6990flmfsp
#
# President Trump draws attention to border crisis securing our Streets..
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# https://t.co/J5iPSoDu…
# NA
# https://t.co/7FqF9b8yNz leaked in alpha group
# NA
# NA
# https://t.co/Rz0YuVFHFd
# https://t.co/Tq1xZHIihP
# NA
# https://t.co/dlbHi081vC
# https://t.co/PXSNHm7vNX
# https://t.co/d2ednGHtbJ
# NA
# NA
# NA
# NA
# NA
# NA
# https:…
# https://t.co/HkcKADKEma
# https://t.co/W7rxNPY8a8
# https://t.co/DHQUaUbD3c
# NA
# https://t.co/KhYgyXhuEL
# https://t.co/kYY96Ekxxy
# https://t.co/B336sQmC97
# NA
# https://t.co/qfXQyqsFaL
# https://t.co/gANZwjzWZM
# https://t.co/JSfBajE9dZ
# https://t.co/rWwx4hMZqt
# NA
# NA
# NA
# NA
# NA
# NA
# https://t.co/M20S9UZSap
# NA
# ...

# %%
with open('twitter_data_2.csv', 'w', encoding='UTF8',newline='') as f:
    writer = csv.writer(f)
    writer.writerow(header)

    # write the data
    for trump in trumps:
        st = trump.text
        print(type(st))
        index = st.rfind("https")
        print(index)
        print(st[index:])
        row = ["P:"+str(trump.id), trump.text, "NA" if (index == -1) else st[index:]]
        writer.writerow(row)
# Out:
# <class 'str'>
# 0
# https://t.co/Kgmx1u37Uk
# <class 'str'>
# -1
# e
# <class 'str'>
# -1
# s
# <class 'str'>
# -1
# …
# <class 'str'>
# -1
# …
# <class 'str'>
# -1
# p
# <class 'str'>
# -1
# 🤔
# <class 'str'>
# -1
# .
# <class 'str'>
# -1
# …
# <class 'str'>
# -1
# d
# <class 'str'>
# 90
# https://t.co/PXSNHm7vNX
# <class 'str'>
# -1
# 🔥
# <class 'str'>
# 79
# https://t.co/d2ednGHtbJ
# <class 'str'>
# -1
# .
# <class 'str'>
# 314
# https://t.co/cCtsKCdsAr
# <class 'str'>
# -1
# !
# <class 'str'>
# -1
# …
# <class 'str'>
# 76
# https://t.co/J2oKDP9tVB
# <class 'str'>
# 0
# https://t.co/mIF9gLnYpp
# <class 'str'>
# -1
# ی
# <class 'str'>
# -1
# p
# <class 'str'>
# 0
# https://t.co/6990flmfsp
#
# President Trump draws attention to border crisis securing our Streets..
# <class 'str'>
# -1
# …
# <class 'str'>
# -1
# …
# <class 'str'>
# -1
# …
# <class 'str'>
# -1
# …
# <class 'str'>
# -1
# …
# <class 'str'>
# -1
# …
# <class 'str'>
# -1
# …
# <class 'str'>
# -1
# …
# <class 'str'>
# -1
# ...
